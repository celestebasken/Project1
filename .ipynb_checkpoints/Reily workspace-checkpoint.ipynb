# %%
# %pip install wbdata
import math
import numpy as np
import wbdata
# Out:
# Collecting wbdata
#   Using cached wbdata-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting appdirs<2.0,>=1.4 (from wbdata)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting backoff<3.0.0,>=2.2.1 (from wbdata)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: cachetools<6.0.0,>=5.3.2 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.5.1)
# Collecting dateparser<2.0.0,>=1.2.0 (from wbdata)
#   Using cached dateparser-1.2.0-py2.py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: decorator<6.0.0,>=5.1.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3.0,>=2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.32.3)
# Collecting shelved-cache<0.4.0,>=0.3.1 (from wbdata)
#   Using cached shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting tabulate<0.9.0,>=0.8.5 (from wbdata)
#   Using cached tabulate-0.8.10-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: python-dateutil in /srv/conda/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz in /srv/conda/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2024.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /srv/conda/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2024.11.6)
# Collecting tzlocal (from dateparser<2.0.0,>=1.2.0->wbdata)
#   Using cached tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil->dateparser<2.0.0,>=1.2.0->wbdata) (1.17.0)
# Using cached wbdata-1.0.0-py3-none-any.whl (18 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
# Using cached shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Using cached tabulate-0.8.10-py3-none-any.whl (29 kB)
# Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# Installing collected packages: appdirs, tzlocal, tabulate, shelved-cache, backoff, dateparser, wbdata
# Successfully installed appdirs-1.4.4 backoff-2.2.1 dateparser-1.2.0 shelved-cache-0.3.1 tabulate-0.8.10 tzlocal-5.2 wbdata-1.0.0
# Note: you may need to restart the kernel to use updated packages.
# Key '2567504219505075553' not in persistent cache.
# Key '9134375496246190790' not in persistent cache.
# Key '8019017608241152443' not in persistent cache.
# Key '1869715225916160439' not in persistent cache.
# Key '5134547327914718745' not in persistent cache.
# Key '5388784740464044708' not in persistent cache.
# Key '7334667624621090305' not in persistent cache.
# Key '-8371570558692883063' not in persistent cache.
# Key '-8208239076826085793' not in persistent cache.
# Key '6548213740929695997' not in persistent cache.
# Key '-8898359817299971236' not in persistent cache.
# Key '-533193764395186757' not in persistent cache.
# Key '2731638337603371549' not in persistent cache.
# Key '-5429748839036523623' not in persistent cache.
# Key '-5175511426487197660' not in persistent cache.
# Key '-1910679324488639354' not in persistent cache.
# Key '-1747347842621842084' not in persistent cache.
# Key '-7931869758537319841' not in persistent cache.
# Key '421043264344143982' not in persistent cache.
# Key '-4412800243989435572' not in persistent cache.
# Key '5872556653080220872' not in persistent cache.
# Key '-4675103112229139260' not in persistent cache.
# Key '2988086372753787174' not in persistent cache.
# Key '-1156033597681254991' not in persistent cache.
# Key '-6212508115614536057' not in persistent cache.
# Key '7928712559855736982' not in persistent cache.
# Key '8092044041722534252' not in persistent cache.
# Key '4401752785768764426' not in persistent cache.
# Key '-8485304551264539642' not in persistent cache.
# Key '2527533407290733534' not in persistent cache.
# Key '-8256021181435891648' not in persistent cache.
# Key '2029335715633764796' not in persistent cache.
# Key '2283573128183090759' not in persistent cache.
# Key '5548405230181649065' not in persistent cache.
# Key '5711736712048446335' not in persistent cache.
# Key '-472785203867031422' not in persistent cache.
# Key '7880127819014432401' not in persistent cache.
# Key '-3999744977954003978' not in persistent cache.
# Key '-5115102865959042325' not in persistent cache.
# Key '2783981442441149159' not in persistent cache.
# Key '-7999573146285476023' not in persistent cache.
# Key '6303050956989033428' not in persistent cache.
# Key '1246576439055752362' not in persistent cache.
# Key '-3058946959183526215' not in persistent cache.
# Key '-2895615477316728945' not in persistent cache.
# Key '-6585906733270498771' not in persistent cache.
# Key '3199213144735740250' not in persistent cache.
# Key '163664412565829938' not in persistent cache.
# Key '3428496514564388244' not in persistent cache.
# Key '-4732890662075506928' not in persistent cache.
# Key '-4478653249526180965' not in persistent cache.
# Key '-8259850436162479484' not in persistent cache.
# Key '-1050489665660825389' not in persistent cache.
# Key '-7235011581576303146' not in persistent cache.
# Key '1117901441305160677' not in persistent cache.
# Key '7684772718046275914' not in persistent cache.
# Key '-476614458593619258' not in persistent cache.
# Key '420112447716245563' not in persistent cache.
# Key '3684944549714803869' not in persistent cache.
# Key '-3106847326370726993' not in persistent cache.
# Key '5885064846421175429' not in persistent cache.
# Key '1579541448181896852' not in persistent cache.
# Key '8788902218683550947' not in persistent cache.
# Key '5098610962729781121' not in persistent cache.
# Key '1022322059346311323' not in persistent cache.
# Key '-6411584055807967117' not in persistent cache.
# Key '-5794423859459897508' not in persistent cache.
# Key '4490933037609758936' not in persistent cache.
# Key '4745170450159084899' not in persistent cache.
# Key '8010002552157643205' not in persistent cache.
# Key '-3227380751050254316' not in persistent cache.
# Key '1988812118108962718' not in persistent cache.
# Key '-1058989644084268250' not in persistent cache.
# Key '5507881632656846987' not in persistent cache.
# Key '-2653505543983048185' not in persistent cache.
# Key '-6155136020657551492' not in persistent cache.
# Key '-5537975824309481883' not in persistent cache.
# Key '8764648278965027568' not in persistent cache.
# Key '3708173761031746502' not in persistent cache.
# Key '-597349637207532075' not in persistent cache.
# Key '6612011133294122020' not in persistent cache.
# Key '2921719877340352194' not in persistent cache.
# Key '1042421433028067444' not in persistent cache.
# Key '-9039156587776699693' not in persistent cache.
# Key '-5774324485778141387' not in persistent cache.
# Key '4511032411291515057' not in persistent cache.
# Key '4765269823840841020' not in persistent cache.
# Key '8030101925839399326' not in persistent cache.
# Key '-3207281377368498195' not in persistent cache.
# Key '2008911491790718839' not in persistent cache.
# Key '-1038890270402512129' not in persistent cache.
# Key '5527981006338603108' not in persistent cache.
# Key '-2633406170301292064' not in persistent cache.
# Key '-8782708552626284068' not in persistent cache.
# Key '-5517876450627725762' not in persistent cache.
# Key '-5263639038078399799' not in persistent cache.
# Key '3728273134713502623' not in persistent cache.
# Key '-577250263525775954' not in persistent cache.
# Key '-413918781658978684' not in persistent cache.
# Key '-4104210037612748510' not in persistent cache.
# Key '-396108794481977476' not in persistent cache.
# Key '4190382703766103179' not in persistent cache.
# Key '-4373760174466448615' not in persistent cache.
# Key '-7409308906636358927' not in persistent cache.
# Key '-4144476804637800621' not in persistent cache.
# Key '-7907506598293327665' not in persistent cache.
# Key '6395117504981181786' not in persistent cache.
# Key '-8786794466729811524' not in persistent cache.
# Key '-8623462984863014254' not in persistent cache.
# Key '3638759172931059605' not in persistent cache.
# Key '-6455071877897028188' not in persistent cache.
# Key '111799398844087049' not in persistent cache.
# Key '-1003558489160951298' not in persistent cache.
# Key '-7152860871485943302' not in persistent cache.
# Key '-3888028769487384996' not in persistent cache.
# Key '-3633791356938059033' not in persistent cache.
# Key '5358120815853843389' not in persistent cache.
# Key '1052597417614564812' not in persistent cache.
# Key '1215928899481362082' not in persistent cache.
# Key '-2474362356472407744' not in persistent cache.
# Key '4648815922935655126' not in persistent cache.
# Key '1613267190765744814' not in persistent cache.
# Key '4878099292764303120' not in persistent cache.
# Key '-3283287883875592052' not in persistent cache.
# Key '-3029050471326266089' not in persistent cache.
# Key '235781630672292217' not in persistent cache.
# Key '399113112539089487' not in persistent cache.
# Key '-5785408803376388270' not in persistent cache.
# Key '2567504219505075553' not in persistent cache.
# Key '9134375496246190790' not in persistent cache.
# Key '8019017608241152443' not in persistent cache.
# Key '1869715225916160439' not in persistent cache.
# Key '5134547327914718745' not in persistent cache.
# Key '5388784740464044708' not in persistent cache.
# Key '7334667624621090305' not in persistent cache.
# Key '-8371570558692883063' not in persistent cache.
# Key '-8208239076826085793' not in persistent cache.
# Key '6548213740929695997' not in persistent cache.
# Key '-8898359817299971236' not in persistent cache.
# Key '-533193764395186757' not in persistent cache.
# Key '2731638337603371549' not in persistent cache.
# Key '-5429748839036523623' not in persistent cache.
# Key '-5175511426487197660' not in persistent cache.
# Key '-1910679324488639354' not in persistent cache.
# Key '-1747347842621842084' not in persistent cache.
# Key '-7931869758537319841' not in persistent cache.
# Key '421043264344143982' not in persistent cache.
# Key '-4412800243989435572' not in persistent cache.
# Key '5872556653080220872' not in persistent cache.
# Key '-4675103112229139260' not in persistent cache.
# Key '2988086372753787174' not in persistent cache.
# Key '-1156033597681254991' not in persistent cache.
# Key '-6212508115614536057' not in persistent cache.
# Key '7928712559855736982' not in persistent cache.
# Key '8092044041722534252' not in persistent cache.
# Key '4401752785768764426' not in persistent cache.
# Key '-8485304551264539642' not in persistent cache.
# Key '2527533407290733534' not in persistent cache.
# Key '-8256021181435891648' not in persistent cache.
# Key '2029335715633764796' not in persistent cache.
# Key '2283573128183090759' not in persistent cache.
# Key '-2310340440116918589' not in persistent cache.
# Key '-6615863838356197166' not in persistent cache.
# Key '593496932145456929' not in persistent cache.
# Key '-3096794323808312897' not in persistent cache.
# Key '-2965806832304782069' not in persistent cache.
# Key '9022453730356687714' not in persistent cache.
# Key '7028082654323788769' not in persistent cache.
# Key '3165938091045908326' not in persistent cache.
# Key '6993903451028163732' not in persistent cache.
# Key '-6478598058718081549' not in persistent cache.
# Key '-8793029250240405733' not in persistent cache.
# Key '-8072908618919817251' not in persistent cache.
# Key '1255972802264794619' not in persistent cache.
# Key '1478565776108931708' not in persistent cache.
# Key '3182654490325254212' not in persistent cache.
# Key '-293213081311572027' not in persistent cache.
# Key '-3730717356603517583' not in persistent cache.
# Key '-2920155488351255626' not in persistent cache.
# Key '4532752815483272103' not in persistent cache.
# Key '2048120973758285840' not in persistent cache.
# Key '8092026959118451071' not in persistent cache.
# Key '-3026065763713966731' not in persistent cache.
# Key '-3821815456134138476' not in persistent cache.
# Key '-1600688487976764613' not in persistent cache.
# Key '-9175672706790378086' not in persistent cache.
# Key '-7420621792691216299' not in persistent cache.
# Key '-298331955146073360' not in persistent cache.
# Key '1486194025212845932' not in persistent cache.
# Key '-5539324890307319412' not in persistent cache.
# Key '-5109652089926687373' not in persistent cache.
# Key '2120908864085659753' not in persistent cache.
# Key '-1377985321397703752' not in persistent cache.
# Key '6620728985730747748' not in persistent cache.
# Key '-1706102118700812976' not in persistent cache.
# Key '-611100499510927004' not in persistent cache.
# Key '-8788439195566335617' not in persistent cache.
# Key '2169900436098546139' not in persistent cache.
# Key '5587600050696480535' not in persistent cache.
# Key '6323647393673807083' not in persistent cache.
# Key '-5332767035338632421' not in persistent cache.
# Key '-714891698899660143' not in persistent cache.
# Key '5393913921844866994' not in persistent cache.
# Key '4680291210844315447' not in persistent cache.
# Key '6140888400638901889' not in persistent cache.
# Key '-6700718124674217873' not in persistent cache.
# Key '986954256075365148' not in persistent cache.
# Key '1898250099667451255' not in persistent cache.
# Key '6227208007711958105' not in persistent cache.
# Key '-3235587751481751747' not in persistent cache.
# Key '9147188391544744001' not in persistent cache.
# Key '8669570902758675372' not in persistent cache.
# Key '-4489462821728750746' not in persistent cache.
# Key '-4431471031708184531' not in persistent cache.
# Key '1721021488462447507' not in persistent cache.
# Key '-8739987761551504798' not in persistent cache.
# Key '9093410818904644382' not in persistent cache.
# Key '-7373444044618987181' not in persistent cache.
# Key '-3775618785321911773' not in persistent cache.
# Key '-900531670604245432' not in persistent cache.
# Key '-6246685137833306125' not in persistent cache.
# Key '-4848271357753542703' not in persistent cache.
# Key '2373629065206488451' not in persistent cache.
# Key '3442663748607012482' not in persistent cache.
# Key '3486378935334473661' not in persistent cache.
# Key '-8049655294044167510' not in persistent cache.
# Key '37788768793442697' not in persistent cache.
# Key '6324045036710019888' not in persistent cache.
# Key '6975255996648736919' not in persistent cache.
# Key '3124116969800537266' not in persistent cache.
# Key '8782860226883498303' not in persistent cache.
# Key '9010369395998679666' not in persistent cache.
# Key '6017104935571938946' not in persistent cache.
# Key '677005728673284158' not in persistent cache.
# Key '349913557386212990' not in persistent cache.
# Key '-6413004741482898992' not in persistent cache.
# Key '3824627516500737904' not in persistent cache.
# Key '-9287859061820458' not in persistent cache.
# Key '3848693310750484299' not in persistent cache.
# Key '-3437078215499192287' not in persistent cache.
# Key '4823379490296659017' not in persistent cache.
# Key '-5662572194861851658' not in persistent cache.
# Key '8535059545758308142' not in persistent cache.
# Key '3832594128991902643' not in persistent cache.
# Key '-6597113307031324228' not in persistent cache.
# Key '-2434738591507429279' not in persistent cache.
# Key '8088767452429304714' not in persistent cache.
# Key '-1124931422307792884' not in persistent cache.
# Key '-2527550297608504061' not in persistent cache.
# Key '-807841397491894890' not in persistent cache.
# Key '6885397457698728296' not in persistent cache.
# Key '5878284142779421028' not in persistent cache.
# Key '-5476689204200318892' not in persistent cache.
# Key '-7187734771482048526' not in persistent cache.
# Key '-2987455571540767076' not in persistent cache.
# Key '-7125249508433244998' not in persistent cache.
# Key '-6063395720158675853' not in persistent cache.
# Key '-5075708986989465596' not in persistent cache.
# Key '-482440789407931316' not in persistent cache.
# Key '304556658344153983' not in persistent cache.
# Key '-5635603346212969659' not in persistent cache.
# Key '1910785953101738998' not in persistent cache.
# Key '-3723592208116448793' not in persistent cache.
# Key '-6759140940286359105' not in persistent cache.
# Key '904048544696567329' not in persistent cache.
# Key '-7257338631943327843' not in persistent cache.
# Key '7045285471331181608' not in persistent cache.
# Key '7662445667679251217' not in persistent cache.
# Key '-7973295018513014432' not in persistent cache.
# Key '8687284522265427555' not in persistent cache.
# Key '-1406546528562660238' not in persistent cache.
# Key '5160324748178454999' not in persistent cache.
# Key '-3001062428461440173' not in persistent cache.
# Key '-6502692905135943480' not in persistent cache.
# Key '1160496579846982954' not in persistent cache.
# Key '8417091394486635580' not in persistent cache.
# Key '-1037740506431013614' not in persistent cache.
# Key '-944906521685924063' not in persistent cache.
# Key '6264454248815730032' not in persistent cache.
# Key '2574162992861960206' not in persistent cache.
# Key '7037606824008834198' not in persistent cache.
# Key '-396299291145444242' not in persistent cache.
# Key '7266890193837482192' not in persistent cache.
# Key '-894496982802412980' not in persistent cache.
# Key '-5038616953237455145' not in persistent cache.
# Key '-4421456756889385536' not in persistent cache.
# Key '2787904013612268559' not in persistent cache.
# Key '-3396617902303209198' not in persistent cache.
# Key '4956295120578254625' not in persistent cache.
# Key '-6923577676390181754' not in persistent cache.
# Key '3361779220679474690' not in persistent cache.
# Key '-139851255995028617' not in persistent cache.
# Key '477308940353040992' not in persistent cache.
# Key '-3666811030082001173' not in persistent cache.
# Key '-8723285548015282239' not in persistent cache.
# Key '5417935127454990800' not in persistent cache.
# Key '-5819448175752906721' not in persistent cache.
# Key '8937004642002875069' not in persistent cache.
# Key '-3915479700361827753' not in persistent cache.
# Key '7097358258193445423' not in persistent cache.
# Key '7714518454541515032' not in persistent cache.
# Key '6599160566536476685' not in persistent cache.
# Key '-4590988692533422305' not in persistent cache.
# Key '3072200792449504129' not in persistent cache.
# Key '-8165182510758393392' not in persistent cache.
# Key '4097039647035680467' not in persistent cache.
# Key '-5996791403792407326' not in persistent cache.
# Key '570079872948707911' not in persistent cache.
# Key '-7591307303691187261' not in persistent cache.
# Key '7353806293343861048' not in persistent cache.
# Key '7970966489691930657' not in persistent cache.
# Key '3826846519256888492' not in persistent cache.
# Key '-1229627998676392574' not in persistent cache.
# Key '-5535151396915671151' not in persistent cache.
# Key '1674209373585982944' not in persistent cache.
# Key '-2016081882367786882' not in persistent cache.
# Key '-3085736991833358997' not in persistent cache.
# Key '-6121285724003269309' not in persistent cache.
# Key '8544261163069983788' not in persistent cache.
# Key '7428903275064945441' not in persistent cache.
# Key '637111398979414579' not in persistent cache.
# Key '3901943500977972885' not in persistent cache.
# Key '-7335439802229924636' not in persistent cache.
# Key '-2119246933070707602' not in persistent cache.
# Key '-5167048695263938570' not in persistent cache.
# Key '1399822581477176667' not in persistent cache.
# Key '-6761564595162718505' not in persistent cache.
# Key '-5864837688852853684' not in persistent cache.
# Key '8800709198220399413' not in persistent cache.
# Key '9054946610769725376' not in persistent cache.
# Key '-399885290147923818' not in persistent cache.
# Key '-4705408688387202395' not in persistent cache.
# Key '2503952082114451700' not in persistent cache.
# Key '-1186339173839318126' not in persistent cache.
# Key '-1253248386738997694' not in persistent cache.
# Key '-1923610954303099819' not in persistent cache.
# Key '5638768256569580146' not in persistent cache.
# Key '4197274170400147766' not in persistent cache.
# Key '4362205902968726980' not in persistent cache.
# Key '-6724653355604081848' not in persistent cache.
# Key '4746710033423540200' not in persistent cache.
# Key '-5148231067834753274' not in persistent cache.
# Key '4759027918634808724' not in persistent cache.
# Key '2026670364684332169' not in persistent cache.
# Key '2087774008491059919' not in persistent cache.
# Key '491694586304585588' not in persistent cache.
# Key '369380253067422105' not in persistent cache.
# Key '2569855733325190645' not in persistent cache.
# Key '-3683903883936703529' not in persistent cache.
# Key '9130131641951787426' not in persistent cache.
# Key '6885400268954193696' not in persistent cache.
# Key '4263513213097071587' not in persistent cache.
# Key '-4996883705276275232' not in persistent cache.
# Key '195610104509890385' not in persistent cache.
# Key '-5678781308421775312' not in persistent cache.
# Key '-4643101513917492386' not in persistent cache.
# Key '-948403747539177097' not in persistent cache.
# Key '-6661553024203838176' not in persistent cache.
# Key '-5263676234938424755' not in persistent cache.
# Key '-2239915225313362887' not in persistent cache.
# Key '8243207799975495385' not in persistent cache.
# Key '-6279026234155583636' not in persistent cache.
# Key '-6714285332701986828' not in persistent cache.
# Key '-8048042764131455502' not in persistent cache.
# Key '-7090764343234815467' not in persistent cache.
# Key '8005954363362993499' not in persistent cache.
# Key '8703403407392178602' not in persistent cache.
# Key '2059327782376310280' not in persistent cache.
# Key '-1249532449890274615' not in persistent cache.
# Key '-6605760121164836945' not in persistent cache.
# Key '8352041791463151612' not in persistent cache.
# Key '7912864293515825328' not in persistent cache.
# Key '-3958653083516357361' not in persistent cache.
# Key '-7472411330182296819' not in persistent cache.
# Key '7953798997058249068' not in persistent cache.
# Key '8584823756542021495' not in persistent cache.
# Key '2367684988573521412' not in persistent cache.
# Key '-989612709746316740' not in persistent cache.
# Key '8369205009937333125' not in persistent cache.
# Key '-1551637466153937108' not in persistent cache.
# Key '6212513978987625880' not in persistent cache.
# Key '1794576077421073796' not in persistent cache.
# Key '4604881664957911799' not in persistent cache.
# Key '826692885637929165' not in persistent cache.
# Key '-199830915017006931' not in persistent cache.
# Key '-5561737451212975566' not in persistent cache.
# Key '2349348519703368122' not in persistent cache.
# Key '-2527624400923046390' not in persistent cache.
# Key '6593475997694643074' not in persistent cache.
# Key '-6775582749734802505' not in persistent cache.
# Key '8416392981970528213' not in persistent cache.
# Key '7615412533477571783' not in persistent cache.
# Key '-6285176753966908920' not in persistent cache.
# Key '-4296788255019371683' not in persistent cache.
# Key '1337839239091145351' not in persistent cache.
# Key '-6685052944884648080' not in persistent cache.
# Key '1361477521378769645' not in persistent cache.
# Key '-1649680809315119238' not in persistent cache.
# Key '-3682718048933562874' not in persistent cache.
# Key '-3704739639037815488' not in persistent cache.
# Key '1309558454752865211' not in persistent cache.
# Key '-8955262322954754839' not in persistent cache.
# Key '542484437739318929' not in persistent cache.
# Key '-8890880206715576307' not in persistent cache.
# Key '2567504219505075553' not in persistent cache.
# Key '9134375496246190790' not in persistent cache.
# Key '8019017608241152443' not in persistent cache.
# Key '1869715225916160439' not in persistent cache.
# Key '5134547327914718745' not in persistent cache.
# Key '5388784740464044708' not in persistent cache.
# Key '7334667624621090305' not in persistent cache.
# Key '-8371570558692883063' not in persistent cache.
# Key '-8208239076826085793' not in persistent cache.
# Key '6548213740929695997' not in persistent cache.
# Key '-8898359817299971236' not in persistent cache.
# Key '-533193764395186757' not in persistent cache.
# Key '2731638337603371549' not in persistent cache.
# Key '-5429748839036523623' not in persistent cache.
# Key '-5175511426487197660' not in persistent cache.
# Key '-1910679324488639354' not in persistent cache.
# Key '-1747347842621842084' not in persistent cache.
# Key '-7931869758537319841' not in persistent cache.
# Key '421043264344143982' not in persistent cache.
# Key '-4412800243989435572' not in persistent cache.
# Key '5872556653080220872' not in persistent cache.
# Key '-4675103112229139260' not in persistent cache.
# Key '2988086372753787174' not in persistent cache.
# Key '-1156033597681254991' not in persistent cache.
# Key '-6212508115614536057' not in persistent cache.
# Key '7928712559855736982' not in persistent cache.
# Key '8092044041722534252' not in persistent cache.
# Key '4401752785768764426' not in persistent cache.
# Key '-8485304551264539642' not in persistent cache.
# Key '2527533407290733534' not in persistent cache.
# Key '-8256021181435891648' not in persistent cache.
# Key '2029335715633764796' not in persistent cache.
# Key '2283573128183090759' not in persistent cache.
# Key '5548405230181649065' not in persistent cache.
# Key '5711736712048446335' not in persistent cache.
# Key '-472785203867031422' not in persistent cache.
# Key '7880127819014432401' not in persistent cache.
# Key '-3999744977954003978' not in persistent cache.
# Key '-5115102865959042325' not in persistent cache.
# Key '2783981442441149159' not in persistent cache.
# Key '-7999573146285476023' not in persistent cache.
# Key '6303050956989033428' not in persistent cache.
# Key '1246576439055752362' not in persistent cache.
# Key '-3058946959183526215' not in persistent cache.
# Key '-2895615477316728945' not in persistent cache.
# Key '-6585906733270498771' not in persistent cache.
# Key '3199213144735740250' not in persistent cache.
# Key '163664412565829938' not in persistent cache.
# Key '3428496514564388244' not in persistent cache.
# Key '-4732890662075506928' not in persistent cache.
# Key '-4478653249526180965' not in persistent cache.
# Key '-8259850436162479484' not in persistent cache.
# Key '-1050489665660825389' not in persistent cache.
# Key '-7235011581576303146' not in persistent cache.
# Key '1117901441305160677' not in persistent cache.
# Key '7684772718046275914' not in persistent cache.
# Key '-476614458593619258' not in persistent cache.
# Key '420112447716245563' not in persistent cache.
# Key '3684944549714803869' not in persistent cache.
# Key '-3106847326370726993' not in persistent cache.
# Key '5885064846421175429' not in persistent cache.
# Key '1579541448181896852' not in persistent cache.
# Key '8788902218683550947' not in persistent cache.
# Key '5098610962729781121' not in persistent cache.
# Key '1022322059346311323' not in persistent cache.
# Key '-6411584055807967117' not in persistent cache.
# Key '-5794423859459897508' not in persistent cache.
# Key '4490933037609758936' not in persistent cache.
# Key '4745170450159084899' not in persistent cache.
# Key '8010002552157643205' not in persistent cache.
# Key '-3227380751050254316' not in persistent cache.
# Key '1988812118108962718' not in persistent cache.
# Key '-1058989644084268250' not in persistent cache.
# Key '5507881632656846987' not in persistent cache.
# Key '-2653505543983048185' not in persistent cache.
# Key '-6155136020657551492' not in persistent cache.
# Key '-5537975824309481883' not in persistent cache.
# Key '8764648278965027568' not in persistent cache.
# Key '3708173761031746502' not in persistent cache.
# Key '-597349637207532075' not in persistent cache.
# Key '6612011133294122020' not in persistent cache.
# Key '2921719877340352194' not in persistent cache.
# Key '1042421433028067444' not in persistent cache.
# Key '-9039156587776699693' not in persistent cache.
# Key '-5774324485778141387' not in persistent cache.
# Key '4511032411291515057' not in persistent cache.
# Key '4765269823840841020' not in persistent cache.
# Key '8030101925839399326' not in persistent cache.
# Key '-3207281377368498195' not in persistent cache.
# Key '2008911491790718839' not in persistent cache.
# Key '-1038890270402512129' not in persistent cache.
# Key '5527981006338603108' not in persistent cache.
# Key '-2633406170301292064' not in persistent cache.
# Key '-8782708552626284068' not in persistent cache.
# Key '-5517876450627725762' not in persistent cache.
# Key '-5263639038078399799' not in persistent cache.
# Key '3728273134713502623' not in persistent cache.
# Key '-577250263525775954' not in persistent cache.
# Key '-413918781658978684' not in persistent cache.
# Key '-4104210037612748510' not in persistent cache.
# Key '-396108794481977476' not in persistent cache.
# Key '4190382703766103179' not in persistent cache.
# Key '-4373760174466448615' not in persistent cache.
# Key '-7409308906636358927' not in persistent cache.
# Key '-4144476804637800621' not in persistent cache.
# Key '-7907506598293327665' not in persistent cache.
# Key '6395117504981181786' not in persistent cache.
# Key '-8786794466729811524' not in persistent cache.
# Key '-8623462984863014254' not in persistent cache.
# Key '3638759172931059605' not in persistent cache.
# Key '-6455071877897028188' not in persistent cache.
# Key '111799398844087049' not in persistent cache.
# Key '-1003558489160951298' not in persistent cache.
# Key '-7152860871485943302' not in persistent cache.
# Key '-3888028769487384996' not in persistent cache.
# Key '-3633791356938059033' not in persistent cache.
# Key '5358120815853843389' not in persistent cache.
# Key '1052597417614564812' not in persistent cache.
# Key '1215928899481362082' not in persistent cache.
# Key '-2474362356472407744' not in persistent cache.
# Key '4648815922935655126' not in persistent cache.
# Key '1613267190765744814' not in persistent cache.
# Key '4878099292764303120' not in persistent cache.
# Key '-3283287883875592052' not in persistent cache.
# Key '-3029050471326266089' not in persistent cache.
# Key '235781630672292217' not in persistent cache.
# Key '399113112539089487' not in persistent cache.
# Key '-5785408803376388270' not in persistent cache.
# Key '2567504219505075553' not in persistent cache.
# Key '9134375496246190790' not in persistent cache.
# Key '8019017608241152443' not in persistent cache.
# Key '1869715225916160439' not in persistent cache.
# Key '5134547327914718745' not in persistent cache.
# Key '5388784740464044708' not in persistent cache.
# Key '7334667624621090305' not in persistent cache.
# Key '-8371570558692883063' not in persistent cache.
# Key '-8208239076826085793' not in persistent cache.
# Key '6548213740929695997' not in persistent cache.
# Key '-8898359817299971236' not in persistent cache.
# Key '-533193764395186757' not in persistent cache.
# Key '2731638337603371549' not in persistent cache.
# Key '-5429748839036523623' not in persistent cache.
# Key '-5175511426487197660' not in persistent cache.
# Key '-1910679324488639354' not in persistent cache.
# Key '-1747347842621842084' not in persistent cache.
# Key '-7931869758537319841' not in persistent cache.
# Key '421043264344143982' not in persistent cache.
# Key '-4412800243989435572' not in persistent cache.
# Key '5872556653080220872' not in persistent cache.
# Key '-4675103112229139260' not in persistent cache.
# Key '2988086372753787174' not in persistent cache.
# Key '-1156033597681254991' not in persistent cache.
# Key '-6212508115614536057' not in persistent cache.
# Key '7928712559855736982' not in persistent cache.
# Key '8092044041722534252' not in persistent cache.
# Key '4401752785768764426' not in persistent cache.
# Key '-8485304551264539642' not in persistent cache.
# Key '2527533407290733534' not in persistent cache.
# Key '-8256021181435891648' not in persistent cache.
# Key '2029335715633764796' not in persistent cache.
# Key '2283573128183090759' not in persistent cache.
# Key '-2310340440116918589' not in persistent cache.
# Key '-6615863838356197166' not in persistent cache.
# Key '593496932145456929' not in persistent cache.
# Key '-3096794323808312897' not in persistent cache.
# Key '-2965806832304782069' not in persistent cache.
# Key '9022453730356687714' not in persistent cache.
# Key '7028082654323788769' not in persistent cache.
# Key '3165938091045908326' not in persistent cache.
# Key '6993903451028163732' not in persistent cache.
# Key '-6478598058718081549' not in persistent cache.
# Key '-8793029250240405733' not in persistent cache.
# Key '-8072908618919817251' not in persistent cache.
# Key '1255972802264794619' not in persistent cache.
# Key '1478565776108931708' not in persistent cache.
# Key '3182654490325254212' not in persistent cache.
# Key '-293213081311572027' not in persistent cache.
# Key '-3730717356603517583' not in persistent cache.
# Key '-2920155488351255626' not in persistent cache.
# Key '4532752815483272103' not in persistent cache.
# Key '2048120973758285840' not in persistent cache.
# Key '8092026959118451071' not in persistent cache.
# Key '-3026065763713966731' not in persistent cache.
# Key '-3821815456134138476' not in persistent cache.
# Key '-1600688487976764613' not in persistent cache.
# Key '-9175672706790378086' not in persistent cache.
# Key '-7420621792691216299' not in persistent cache.
# Key '-298331955146073360' not in persistent cache.
# Key '1486194025212845932' not in persistent cache.
# Key '-5539324890307319412' not in persistent cache.
# Key '-5109652089926687373' not in persistent cache.
# Key '2120908864085659753' not in persistent cache.
# Key '-1377985321397703752' not in persistent cache.
# Key '6620728985730747748' not in persistent cache.
# Key '-1706102118700812976' not in persistent cache.
# Key '-611100499510927004' not in persistent cache.
# Key '-8788439195566335617' not in persistent cache.
# Key '2169900436098546139' not in persistent cache.
# Key '5587600050696480535' not in persistent cache.
# Key '6323647393673807083' not in persistent cache.
# Key '-5332767035338632421' not in persistent cache.
# Key '-714891698899660143' not in persistent cache.
# Key '5393913921844866994' not in persistent cache.
# Key '4680291210844315447' not in persistent cache.
# Key '6140888400638901889' not in persistent cache.
# Key '-6700718124674217873' not in persistent cache.
# Key '986954256075365148' not in persistent cache.
# Key '1898250099667451255' not in persistent cache.
# Key '6227208007711958105' not in persistent cache.
# Key '-3235587751481751747' not in persistent cache.
# Key '9147188391544744001' not in persistent cache.
# Key '8669570902758675372' not in persistent cache.
# Key '-4489462821728750746' not in persistent cache.
# Key '-4431471031708184531' not in persistent cache.
# Key '1721021488462447507' not in persistent cache.
# Key '-8739987761551504798' not in persistent cache.
# Key '9093410818904644382' not in persistent cache.
# Key '-7373444044618987181' not in persistent cache.
# Key '-3775618785321911773' not in persistent cache.
# Key '-900531670604245432' not in persistent cache.
# Key '-6246685137833306125' not in persistent cache.
# Key '-4848271357753542703' not in persistent cache.
# Key '2373629065206488451' not in persistent cache.
# Key '3442663748607012482' not in persistent cache.
# Key '3486378935334473661' not in persistent cache.
# Key '-8049655294044167510' not in persistent cache.
# Key '37788768793442697' not in persistent cache.
# Key '6324045036710019888' not in persistent cache.
# Key '6975255996648736919' not in persistent cache.
# Key '3124116969800537266' not in persistent cache.
# Key '8782860226883498303' not in persistent cache.
# Key '9010369395998679666' not in persistent cache.
# Key '6017104935571938946' not in persistent cache.
# Key '677005728673284158' not in persistent cache.
# Key '349913557386212990' not in persistent cache.
# Key '-6413004741482898992' not in persistent cache.
# Key '3824627516500737904' not in persistent cache.
# Key '-9287859061820458' not in persistent cache.
# Key '3848693310750484299' not in persistent cache.
# Key '-3437078215499192287' not in persistent cache.
# Key '4823379490296659017' not in persistent cache.
# Key '-5662572194861851658' not in persistent cache.
# Key '8535059545758308142' not in persistent cache.
# Key '3832594128991902643' not in persistent cache.
# Key '-6597113307031324228' not in persistent cache.
# Key '-2434738591507429279' not in persistent cache.
# Key '8088767452429304714' not in persistent cache.
# Key '-1124931422307792884' not in persistent cache.
# Key '-2527550297608504061' not in persistent cache.
# Key '-807841397491894890' not in persistent cache.
# Key '6885397457698728296' not in persistent cache.
# Key '5878284142779421028' not in persistent cache.
# Key '-5476689204200318892' not in persistent cache.
# Key '-7187734771482048526' not in persistent cache.
# Key '-2987455571540767076' not in persistent cache.
# Key '-7125249508433244998' not in persistent cache.
# Key '-6063395720158675853' not in persistent cache.
# Key '-5075708986989465596' not in persistent cache.
# Key '-482440789407931316' not in persistent cache.
# Key '304556658344153983' not in persistent cache.
# Key '-5635603346212969659' not in persistent cache.
# Key '1910785953101738998' not in persistent cache.
# Key '-3723592208116448793' not in persistent cache.
# Key '-6759140940286359105' not in persistent cache.
# Key '904048544696567329' not in persistent cache.
# Key '-7257338631943327843' not in persistent cache.
# Key '7045285471331181608' not in persistent cache.
# Key '7662445667679251217' not in persistent cache.
# Key '-7973295018513014432' not in persistent cache.
# Key '8687284522265427555' not in persistent cache.
# Key '-1406546528562660238' not in persistent cache.
# Key '5160324748178454999' not in persistent cache.
# Key '-3001062428461440173' not in persistent cache.
# Key '-6502692905135943480' not in persistent cache.
# Key '1160496579846982954' not in persistent cache.
# Key '8417091394486635580' not in persistent cache.
# Key '-1037740506431013614' not in persistent cache.
# Key '-944906521685924063' not in persistent cache.
# Key '6264454248815730032' not in persistent cache.
# Key '2574162992861960206' not in persistent cache.
# Key '7037606824008834198' not in persistent cache.
# Key '-396299291145444242' not in persistent cache.
# Key '7266890193837482192' not in persistent cache.
# Key '-894496982802412980' not in persistent cache.
# Key '-5038616953237455145' not in persistent cache.
# Key '-4421456756889385536' not in persistent cache.
# Key '2787904013612268559' not in persistent cache.
# Key '-3396617902303209198' not in persistent cache.
# Key '4956295120578254625' not in persistent cache.
# Key '-6923577676390181754' not in persistent cache.
# Key '3361779220679474690' not in persistent cache.
# Key '-139851255995028617' not in persistent cache.
# Key '477308940353040992' not in persistent cache.
# Key '-3666811030082001173' not in persistent cache.
# Key '-8723285548015282239' not in persistent cache.
# Key '5417935127454990800' not in persistent cache.
# Key '-5819448175752906721' not in persistent cache.
# Key '8937004642002875069' not in persistent cache.
# Key '-3915479700361827753' not in persistent cache.
# Key '7097358258193445423' not in persistent cache.
# Key '7714518454541515032' not in persistent cache.
# Key '6599160566536476685' not in persistent cache.
# Key '-4590988692533422305' not in persistent cache.
# Key '3072200792449504129' not in persistent cache.
# Key '-8165182510758393392' not in persistent cache.
# Key '4097039647035680467' not in persistent cache.
# Key '-5996791403792407326' not in persistent cache.
# Key '570079872948707911' not in persistent cache.
# Key '-7591307303691187261' not in persistent cache.
# Key '7353806293343861048' not in persistent cache.
# Key '7970966489691930657' not in persistent cache.
# Key '3826846519256888492' not in persistent cache.
# Key '-1229627998676392574' not in persistent cache.
# Key '-5535151396915671151' not in persistent cache.
# Key '1674209373585982944' not in persistent cache.
# Key '-2016081882367786882' not in persistent cache.
# Key '-3085736991833358997' not in persistent cache.
# Key '-6121285724003269309' not in persistent cache.
# Key '8544261163069983788' not in persistent cache.
# Key '7428903275064945441' not in persistent cache.
# Key '637111398979414579' not in persistent cache.
# Key '3901943500977972885' not in persistent cache.
# Key '-7335439802229924636' not in persistent cache.
# Key '-2119246933070707602' not in persistent cache.
# Key '-5167048695263938570' not in persistent cache.
# Key '1399822581477176667' not in persistent cache.
# Key '-6761564595162718505' not in persistent cache.
# Key '-5864837688852853684' not in persistent cache.
# Key '8800709198220399413' not in persistent cache.
# Key '9054946610769725376' not in persistent cache.
# Key '-399885290147923818' not in persistent cache.
# Key '-4705408688387202395' not in persistent cache.
# Key '2503952082114451700' not in persistent cache.
# Key '-1186339173839318126' not in persistent cache.
# Key '-1253248386738997694' not in persistent cache.
# Key '-1923610954303099819' not in persistent cache.
# Key '5638768256569580146' not in persistent cache.
# Key '4197274170400147766' not in persistent cache.
# Key '4362205902968726980' not in persistent cache.
# Key '-6724653355604081848' not in persistent cache.
# Key '4746710033423540200' not in persistent cache.
# Key '-5148231067834753274' not in persistent cache.
# Key '4759027918634808724' not in persistent cache.
# Key '2026670364684332169' not in persistent cache.
# Key '2087774008491059919' not in persistent cache.
# Key '491694586304585588' not in persistent cache.
# Key '369380253067422105' not in persistent cache.
# Key '2569855733325190645' not in persistent cache.
# Key '-3683903883936703529' not in persistent cache.
# Key '9130131641951787426' not in persistent cache.
# Key '6885400268954193696' not in persistent cache.
# Key '4263513213097071587' not in persistent cache.
# Key '-4996883705276275232' not in persistent cache.
# Key '195610104509890385' not in persistent cache.
# Key '-5678781308421775312' not in persistent cache.
# Key '-4643101513917492386' not in persistent cache.
# Key '-948403747539177097' not in persistent cache.
# Key '-6661553024203838176' not in persistent cache.
# Key '-5263676234938424755' not in persistent cache.
# Key '-2239915225313362887' not in persistent cache.
# Key '8243207799975495385' not in persistent cache.
# Key '-6279026234155583636' not in persistent cache.
# Key '-6714285332701986828' not in persistent cache.
# Key '-8048042764131455502' not in persistent cache.
# Key '-7090764343234815467' not in persistent cache.
# Key '8005954363362993499' not in persistent cache.
# Key '8703403407392178602' not in persistent cache.
# Key '2059327782376310280' not in persistent cache.
# Key '-1249532449890274615' not in persistent cache.
# Key '-6605760121164836945' not in persistent cache.
# Key '8352041791463151612' not in persistent cache.
# Key '7912864293515825328' not in persistent cache.
# Key '-3958653083516357361' not in persistent cache.
# Key '-7472411330182296819' not in persistent cache.
# Key '7953798997058249068' not in persistent cache.
# Key '8584823756542021495' not in persistent cache.
# Key '2367684988573521412' not in persistent cache.
# Key '-989612709746316740' not in persistent cache.
# Key '8369205009937333125' not in persistent cache.
# Key '-1551637466153937108' not in persistent cache.
# Key '6212513978987625880' not in persistent cache.
# Key '1794576077421073796' not in persistent cache.
# Key '4604881664957911799' not in persistent cache.
# Key '826692885637929165' not in persistent cache.
# Key '-199830915017006931' not in persistent cache.
# Key '-5561737451212975566' not in persistent cache.
# Key '2349348519703368122' not in persistent cache.
# Key '-2527624400923046390' not in persistent cache.
# Key '6593475997694643074' not in persistent cache.
# Key '-6775582749734802505' not in persistent cache.
# Key '8416392981970528213' not in persistent cache.
# Key '7615412533477571783' not in persistent cache.
# Key '-6285176753966908920' not in persistent cache.
# Key '-4296788255019371683' not in persistent cache.
# Key '1337839239091145351' not in persistent cache.
# Key '-6685052944884648080' not in persistent cache.
# Key '1361477521378769645' not in persistent cache.
# Key '-1649680809315119238' not in persistent cache.
# Key '-3682718048933562874' not in persistent cache.
# Key '-3704739639037815488' not in persistent cache.
# Key '1309558454752865211' not in persistent cache.
# Key '-8955262322954754839' not in persistent cache.
# Key '542484437739318929' not in persistent cache.
# Key '-8890880206715576307' not in persistent cache.
# Key '2567504219505075553' not in persistent cache.
# Key '9134375496246190790' not in persistent cache.
# Key '8019017608241152443' not in persistent cache.
# Key '1869715225916160439' not in persistent cache.
# Key '5134547327914718745' not in persistent cache.
# Key '5388784740464044708' not in persistent cache.
# Key '7334667624621090305' not in persistent cache.
# Key '-8371570558692883063' not in persistent cache.
# Key '-8208239076826085793' not in persistent cache.
# Key '6548213740929695997' not in persistent cache.
# Key '-8898359817299971236' not in persistent cache.
# Key '-533193764395186757' not in persistent cache.
# Key '2731638337603371549' not in persistent cache.
# Key '-5429748839036523623' not in persistent cache.
# Key '-5175511426487197660' not in persistent cache.
# Key '-1910679324488639354' not in persistent cache.
# Key '-1747347842621842084' not in persistent cache.
# Key '-7931869758537319841' not in persistent cache.
# Key '421043264344143982' not in persistent cache.
# Key '-4412800243989435572' not in persistent cache.
# Key '5872556653080220872' not in persistent cache.
# Key '-4675103112229139260' not in persistent cache.
# Key '2988086372753787174' not in persistent cache.
# Key '-1156033597681254991' not in persistent cache.
# Key '-6212508115614536057' not in persistent cache.
# Key '7928712559855736982' not in persistent cache.
# Key '8092044041722534252' not in persistent cache.
# Key '4401752785768764426' not in persistent cache.
# Key '-8485304551264539642' not in persistent cache.
# Key '2527533407290733534' not in persistent cache.
# Key '-8256021181435891648' not in persistent cache.
# Key '2029335715633764796' not in persistent cache.
# Key '2283573128183090759' not in persistent cache.
# Key '5548405230181649065' not in persistent cache.
# Key '5711736712048446335' not in persistent cache.
# Key '-472785203867031422' not in persistent cache.
# Key '7880127819014432401' not in persistent cache.
# Key '-3999744977954003978' not in persistent cache.
# Key '-5115102865959042325' not in persistent cache.
# Key '2783981442441149159' not in persistent cache.
# Key '-7999573146285476023' not in persistent cache.
# Key '6303050956989033428' not in persistent cache.
# Key '1246576439055752362' not in persistent cache.
# Key '-3058946959183526215' not in persistent cache.
# Key '-2895615477316728945' not in persistent cache.
# Key '-6585906733270498771' not in persistent cache.
# Key '3199213144735740250' not in persistent cache.
# Key '163664412565829938' not in persistent cache.
# Key '3428496514564388244' not in persistent cache.
# Key '-4732890662075506928' not in persistent cache.
# Key '-4478653249526180965' not in persistent cache.
# Key '-8259850436162479484' not in persistent cache.
# Key '-1050489665660825389' not in persistent cache.
# Key '-7235011581576303146' not in persistent cache.
# Key '1117901441305160677' not in persistent cache.
# Key '7684772718046275914' not in persistent cache.
# Key '-476614458593619258' not in persistent cache.
# Key '420112447716245563' not in persistent cache.
# Key '3684944549714803869' not in persistent cache.
# Key '-3106847326370726993' not in persistent cache.
# Key '5885064846421175429' not in persistent cache.
# Key '1579541448181896852' not in persistent cache.
# Key '8788902218683550947' not in persistent cache.
# Key '5098610962729781121' not in persistent cache.
# Key '1022322059346311323' not in persistent cache.
# Key '-6411584055807967117' not in persistent cache.
# Key '-5794423859459897508' not in persistent cache.
# Key '4490933037609758936' not in persistent cache.
# Key '4745170450159084899' not in persistent cache.
# ...
# Key '-8782708552626284068' not in persistent cache.
# Key '-5517876450627725762' not in persistent cache.
# Key '-5263639038078399799' not in persistent cache.
# Key '3728273134713502623' not in persistent cache.
# Key '-577250263525775954' not in persistent cache.
# Key '-413918781658978684' not in persistent cache.
# Key '-4104210037612748510' not in persistent cache.
# Key '-396108794481977476' not in persistent cache.
# Key '4190382703766103179' not in persistent cache.
# Key '-4373760174466448615' not in persistent cache.
# Key '-7409308906636358927' not in persistent cache.
# Key '-4144476804637800621' not in persistent cache.
# Key '-7907506598293327665' not in persistent cache.
# Key '6395117504981181786' not in persistent cache.
# Key '-8786794466729811524' not in persistent cache.
# Key '-8623462984863014254' not in persistent cache.
# Key '3638759172931059605' not in persistent cache.
# Key '-6455071877897028188' not in persistent cache.
# Key '111799398844087049' not in persistent cache.
# Key '-1003558489160951298' not in persistent cache.
# Key '-7152860871485943302' not in persistent cache.
# Key '-3888028769487384996' not in persistent cache.
# Key '-3633791356938059033' not in persistent cache.
# Key '5358120815853843389' not in persistent cache.
# Key '1052597417614564812' not in persistent cache.
# Key '1215928899481362082' not in persistent cache.
# Key '-2474362356472407744' not in persistent cache.
# Key '4648815922935655126' not in persistent cache.
# Key '1613267190765744814' not in persistent cache.
# Key '4878099292764303120' not in persistent cache.
# Key '-3283287883875592052' not in persistent cache.
# Key '-3029050471326266089' not in persistent cache.
# Key '235781630672292217' not in persistent cache.
# Key '399113112539089487' not in persistent cache.
# Key '-5785408803376388270' not in persistent cache.
# Key '2567504219505075553' not in persistent cache.
# Key '9134375496246190790' not in persistent cache.
# Key '8019017608241152443' not in persistent cache.
# Key '1869715225916160439' not in persistent cache.
# Key '5134547327914718745' not in persistent cache.
# Key '5388784740464044708' not in persistent cache.
# Key '7334667624621090305' not in persistent cache.
# Key '-8371570558692883063' not in persistent cache.
# Key '-8208239076826085793' not in persistent cache.
# Key '6548213740929695997' not in persistent cache.
# Key '-8898359817299971236' not in persistent cache.
# Key '-533193764395186757' not in persistent cache.
# Key '2731638337603371549' not in persistent cache.
# Key '-5429748839036523623' not in persistent cache.
# Key '-5175511426487197660' not in persistent cache.
# Key '-1910679324488639354' not in persistent cache.
# Key '-1747347842621842084' not in persistent cache.
# Key '-7931869758537319841' not in persistent cache.
# Key '421043264344143982' not in persistent cache.
# Key '-4412800243989435572' not in persistent cache.
# Key '5872556653080220872' not in persistent cache.
# Key '-4675103112229139260' not in persistent cache.
# Key '2988086372753787174' not in persistent cache.
# Key '-1156033597681254991' not in persistent cache.
# Key '-6212508115614536057' not in persistent cache.
# Key '7928712559855736982' not in persistent cache.
# Key '8092044041722534252' not in persistent cache.
# Key '4401752785768764426' not in persistent cache.
# Key '-8485304551264539642' not in persistent cache.
# Key '2527533407290733534' not in persistent cache.
# Key '-8256021181435891648' not in persistent cache.
# Key '2029335715633764796' not in persistent cache.
# Key '2283573128183090759' not in persistent cache.
# Key '-2310340440116918589' not in persistent cache.
# Key '-6615863838356197166' not in persistent cache.
# Key '593496932145456929' not in persistent cache.
# Key '-3096794323808312897' not in persistent cache.
# Key '-2965806832304782069' not in persistent cache.
# Key '9022453730356687714' not in persistent cache.
# Key '7028082654323788769' not in persistent cache.
# Key '3165938091045908326' not in persistent cache.
# Key '6993903451028163732' not in persistent cache.
# Key '-6478598058718081549' not in persistent cache.
# Key '-8793029250240405733' not in persistent cache.
# Key '-8072908618919817251' not in persistent cache.
# Key '1255972802264794619' not in persistent cache.
# Key '1478565776108931708' not in persistent cache.
# Key '3182654490325254212' not in persistent cache.
# Key '-293213081311572027' not in persistent cache.
# Key '-3730717356603517583' not in persistent cache.
# Key '-2920155488351255626' not in persistent cache.
# Key '4532752815483272103' not in persistent cache.
# Key '2048120973758285840' not in persistent cache.
# Key '8092026959118451071' not in persistent cache.
# Key '-3026065763713966731' not in persistent cache.
# Key '-3821815456134138476' not in persistent cache.
# Key '-1600688487976764613' not in persistent cache.
# Key '-9175672706790378086' not in persistent cache.
# Key '-7420621792691216299' not in persistent cache.
# Key '-298331955146073360' not in persistent cache.
# Key '1486194025212845932' not in persistent cache.
# Key '-5539324890307319412' not in persistent cache.
# Key '-5109652089926687373' not in persistent cache.
# Key '2120908864085659753' not in persistent cache.
# Key '-1377985321397703752' not in persistent cache.
# Key '6620728985730747748' not in persistent cache.
# Key '-1706102118700812976' not in persistent cache.
# Key '-611100499510927004' not in persistent cache.
# Key '-8788439195566335617' not in persistent cache.
# Key '2169900436098546139' not in persistent cache.
# Key '5587600050696480535' not in persistent cache.
# Key '6323647393673807083' not in persistent cache.
# Key '-5332767035338632421' not in persistent cache.
# Key '-714891698899660143' not in persistent cache.
# Key '5393913921844866994' not in persistent cache.
# Key '4680291210844315447' not in persistent cache.
# Key '6140888400638901889' not in persistent cache.
# Key '-6700718124674217873' not in persistent cache.
# Key '986954256075365148' not in persistent cache.
# Key '1898250099667451255' not in persistent cache.
# Key '6227208007711958105' not in persistent cache.
# Key '-3235587751481751747' not in persistent cache.
# Key '9147188391544744001' not in persistent cache.
# Key '8669570902758675372' not in persistent cache.
# Key '-4489462821728750746' not in persistent cache.
# Key '-4431471031708184531' not in persistent cache.
# Key '1721021488462447507' not in persistent cache.
# Key '-8739987761551504798' not in persistent cache.
# Key '9093410818904644382' not in persistent cache.
# Key '-7373444044618987181' not in persistent cache.
# Key '-3775618785321911773' not in persistent cache.
# Key '-900531670604245432' not in persistent cache.
# Key '-6246685137833306125' not in persistent cache.
# Key '-4848271357753542703' not in persistent cache.
# Key '2373629065206488451' not in persistent cache.
# Key '3442663748607012482' not in persistent cache.
# Key '3486378935334473661' not in persistent cache.
# Key '-8049655294044167510' not in persistent cache.
# Key '37788768793442697' not in persistent cache.
# Key '6324045036710019888' not in persistent cache.
# Key '6975255996648736919' not in persistent cache.
# Key '3124116969800537266' not in persistent cache.
# Key '8782860226883498303' not in persistent cache.
# Key '9010369395998679666' not in persistent cache.
# Key '6017104935571938946' not in persistent cache.
# Key '677005728673284158' not in persistent cache.
# Key '349913557386212990' not in persistent cache.
# Key '-6413004741482898992' not in persistent cache.
# Key '3824627516500737904' not in persistent cache.
# Key '-9287859061820458' not in persistent cache.
# Key '3848693310750484299' not in persistent cache.
# Key '-3437078215499192287' not in persistent cache.
# Key '4823379490296659017' not in persistent cache.
# Key '-5662572194861851658' not in persistent cache.
# Key '8535059545758308142' not in persistent cache.
# Key '3832594128991902643' not in persistent cache.
# Key '-6597113307031324228' not in persistent cache.
# Key '-2434738591507429279' not in persistent cache.
# Key '8088767452429304714' not in persistent cache.
# Key '-1124931422307792884' not in persistent cache.
# Key '-2527550297608504061' not in persistent cache.
# Key '-807841397491894890' not in persistent cache.
# Key '6885397457698728296' not in persistent cache.
# Key '5878284142779421028' not in persistent cache.
# Key '-5476689204200318892' not in persistent cache.
# Key '-7187734771482048526' not in persistent cache.
# Key '-2987455571540767076' not in persistent cache.
# Key '-7125249508433244998' not in persistent cache.
# Key '-6063395720158675853' not in persistent cache.
# Key '-5075708986989465596' not in persistent cache.
# Key '-482440789407931316' not in persistent cache.
# Key '304556658344153983' not in persistent cache.
# Key '-5635603346212969659' not in persistent cache.
# Key '1910785953101738998' not in persistent cache.
# Key '-3723592208116448793' not in persistent cache.
# Key '-6759140940286359105' not in persistent cache.
# Key '904048544696567329' not in persistent cache.
# Key '-7257338631943327843' not in persistent cache.
# Key '7045285471331181608' not in persistent cache.
# Key '7662445667679251217' not in persistent cache.
# Key '-7973295018513014432' not in persistent cache.
# Key '8687284522265427555' not in persistent cache.
# Key '-1406546528562660238' not in persistent cache.
# Key '5160324748178454999' not in persistent cache.
# Key '-3001062428461440173' not in persistent cache.
# Key '-6502692905135943480' not in persistent cache.
# Key '1160496579846982954' not in persistent cache.
# Key '8417091394486635580' not in persistent cache.
# Key '-1037740506431013614' not in persistent cache.
# Key '-944906521685924063' not in persistent cache.
# Key '6264454248815730032' not in persistent cache.
# Key '2574162992861960206' not in persistent cache.
# Key '7037606824008834198' not in persistent cache.
# Key '-396299291145444242' not in persistent cache.
# Key '7266890193837482192' not in persistent cache.
# Key '-894496982802412980' not in persistent cache.
# Key '-5038616953237455145' not in persistent cache.
# Key '-4421456756889385536' not in persistent cache.
# Key '2787904013612268559' not in persistent cache.
# Key '-3396617902303209198' not in persistent cache.
# Key '4956295120578254625' not in persistent cache.
# Key '-6923577676390181754' not in persistent cache.
# Key '3361779220679474690' not in persistent cache.
# Key '-139851255995028617' not in persistent cache.
# Key '477308940353040992' not in persistent cache.
# Key '-3666811030082001173' not in persistent cache.
# Key '-8723285548015282239' not in persistent cache.
# Key '5417935127454990800' not in persistent cache.
# Key '-5819448175752906721' not in persistent cache.
# Key '8937004642002875069' not in persistent cache.
# Key '-3915479700361827753' not in persistent cache.
# Key '7097358258193445423' not in persistent cache.
# Key '7714518454541515032' not in persistent cache.
# Key '6599160566536476685' not in persistent cache.
# Key '-4590988692533422305' not in persistent cache.
# Key '3072200792449504129' not in persistent cache.
# Key '-8165182510758393392' not in persistent cache.
# Key '4097039647035680467' not in persistent cache.
# Key '-5996791403792407326' not in persistent cache.
# Key '570079872948707911' not in persistent cache.
# Key '-7591307303691187261' not in persistent cache.
# Key '7353806293343861048' not in persistent cache.
# Key '7970966489691930657' not in persistent cache.
# Key '3826846519256888492' not in persistent cache.
# Key '-1229627998676392574' not in persistent cache.
# Key '-5535151396915671151' not in persistent cache.
# Key '1674209373585982944' not in persistent cache.
# Key '-2016081882367786882' not in persistent cache.
# Key '-3085736991833358997' not in persistent cache.
# Key '-6121285724003269309' not in persistent cache.
# Key '8544261163069983788' not in persistent cache.
# Key '7428903275064945441' not in persistent cache.
# Key '637111398979414579' not in persistent cache.
# Key '3901943500977972885' not in persistent cache.
# Key '-7335439802229924636' not in persistent cache.
# Key '-2119246933070707602' not in persistent cache.
# Key '-5167048695263938570' not in persistent cache.
# Key '1399822581477176667' not in persistent cache.
# Key '-6761564595162718505' not in persistent cache.
# Key '-5864837688852853684' not in persistent cache.
# Key '8800709198220399413' not in persistent cache.
# Key '9054946610769725376' not in persistent cache.
# Key '-399885290147923818' not in persistent cache.
# Key '-4705408688387202395' not in persistent cache.
# Key '2503952082114451700' not in persistent cache.
# Key '-1186339173839318126' not in persistent cache.
# Key '-1253248386738997694' not in persistent cache.
# Key '-1923610954303099819' not in persistent cache.
# Key '5638768256569580146' not in persistent cache.
# Key '4197274170400147766' not in persistent cache.
# Key '4362205902968726980' not in persistent cache.
# Key '-6724653355604081848' not in persistent cache.
# Key '4746710033423540200' not in persistent cache.
# Key '-5148231067834753274' not in persistent cache.
# Key '4759027918634808724' not in persistent cache.
# Key '2026670364684332169' not in persistent cache.
# Key '2087774008491059919' not in persistent cache.
# Key '491694586304585588' not in persistent cache.
# Key '369380253067422105' not in persistent cache.
# Key '2569855733325190645' not in persistent cache.
# Key '-3683903883936703529' not in persistent cache.
# Key '9130131641951787426' not in persistent cache.
# Key '6885400268954193696' not in persistent cache.
# Key '4263513213097071587' not in persistent cache.
# Key '-4996883705276275232' not in persistent cache.
# Key '195610104509890385' not in persistent cache.
# Key '-5678781308421775312' not in persistent cache.
# Key '-4643101513917492386' not in persistent cache.
# Key '-948403747539177097' not in persistent cache.
# Key '-6661553024203838176' not in persistent cache.
# Key '-5263676234938424755' not in persistent cache.
# Key '-2239915225313362887' not in persistent cache.
# Key '8243207799975495385' not in persistent cache.
# Key '-6279026234155583636' not in persistent cache.
# Key '-6714285332701986828' not in persistent cache.
# Key '-8048042764131455502' not in persistent cache.
# Key '-7090764343234815467' not in persistent cache.
# Key '8005954363362993499' not in persistent cache.
# Key '8703403407392178602' not in persistent cache.
# Key '2059327782376310280' not in persistent cache.
# Key '-1249532449890274615' not in persistent cache.
# Key '-6605760121164836945' not in persistent cache.
# Key '8352041791463151612' not in persistent cache.
# Key '7912864293515825328' not in persistent cache.
# Key '-3958653083516357361' not in persistent cache.
# Key '-7472411330182296819' not in persistent cache.
# Key '7953798997058249068' not in persistent cache.
# Key '8584823756542021495' not in persistent cache.
# Key '2367684988573521412' not in persistent cache.
# Key '-989612709746316740' not in persistent cache.
# Key '8369205009937333125' not in persistent cache.
# Key '-1551637466153937108' not in persistent cache.
# Key '6212513978987625880' not in persistent cache.
# Key '1794576077421073796' not in persistent cache.
# Key '4604881664957911799' not in persistent cache.
# Key '826692885637929165' not in persistent cache.
# Key '-199830915017006931' not in persistent cache.
# Key '-5561737451212975566' not in persistent cache.
# Key '2349348519703368122' not in persistent cache.
# Key '-2527624400923046390' not in persistent cache.
# Key '6593475997694643074' not in persistent cache.
# Key '-6775582749734802505' not in persistent cache.
# Key '8416392981970528213' not in persistent cache.
# Key '7615412533477571783' not in persistent cache.
# Key '-6285176753966908920' not in persistent cache.
# Key '-4296788255019371683' not in persistent cache.
# Key '1337839239091145351' not in persistent cache.
# Key '-6685052944884648080' not in persistent cache.
# Key '1361477521378769645' not in persistent cache.
# Key '-1649680809315119238' not in persistent cache.
# Key '-3682718048933562874' not in persistent cache.
# Key '-3704739639037815488' not in persistent cache.
# Key '1309558454752865211' not in persistent cache.
# Key '-8955262322954754839' not in persistent cache.
# Key '542484437739318929' not in persistent cache.
# Key '-8890880206715576307' not in persistent cache.

# %% [markdown]
# ## [A] Population Statistics
#
# This function returns a query response to the question: 'In [year] how many [people/males/females] aged [low] to [high] were living in [the world/region/country]?'
#
#  Please note, this function was designed to be able to answer **only** the regions of countries targeted in Operation Condor, as that is the main focus region for our team.

# %%
import math
#def population(year,sex,age_low, age_high,place):
SOURCE = 40

def age_floor_lessthan_25(age_low, age_high, labels, sex):
    
    for i in np.arange(age_low, age_high+1):
        
            if sex == 'males':
                #labels[f'SP.POP.AG{str(i).zfill(2)}.MA.IN'] = f'SP.POP.AG{str(i).zfill(2)}.MA.IN'
                labels[f'SP.POP.AG{str(i).zfill(2)}.MA.IN'] = f'Males {str(i).zfill(2)}'
            elif sex == 'females':
                labels[f'SP.POP.AG{str(i).zfill(2)}.FE.IN'] = f'Females {str(i).zfill(2)}'
                #labels[f'SP.POP.AG{str(i).zfill(2)}.FE.IN'] = f'SP.POP.AG{str(i).zfill(2)}.FE.IN'
            else:
                #labels[f'SP.POP.AG{str(i).zfill(2)}.MA.IN'] = f'SP.POP.AG{str(i).zfill(2)}.MA.IN'
                #labels[f'SP.POP.AG{str(i).zfill(2)}.FE.IN'] = f'SP.POP.AG{str(i).zfill(2)}.FE.IN'   
                labels[f'SP.POP.AG{str(i).zfill(2)}.FE.IN'] = f'Females {str(i).zfill(2)}'
                labels[f'SP.POP.AG{str(i).zfill(2)}.MA.IN'] = f'Males {str(i).zfill(2)}'
                
def age_floor_greaterthan_25(age_low, age_high, labels, sex):
        age_floor = math.floor(age_low /5) * 5
        age_ceiling = math.ceil((age_high+1)/5)*5 
        floor_str = str(age_floor).zfill(2)
        num_ranges = (age_ceiling - age_floor) / 5
        for i in np.arange(num_ranges):
            lower_str = str(int(age_floor+5*i))
            higher_str = str(int(age_floor+5*i+4))
             #override if age is >=80
            if lower_str >='80':
                lower_str = "80"
                higher_str = 'UP'
            if sex == 'males':
                labels[f'SP.POP.{lower_str}{higher_str}.MA'] = f'Males {lower_str}{higher_str}'
            elif sex == 'females':
                labels[f'SP.POP.{lower_str}{higher_str}.FE'] = f'Females {lower_str}{higher_str}'
            else:
                #labels[f'SP.POP.AG{str(i).zfill(2)}.FE.IN'] = f'SP.POP.AG{str(i).zfill(2)}.FE'
                labels[f'SP.POP.{lower_str}{higher_str}.FE'] = f'Females {lower_str}{higher_str}'
                labels[f'SP.POP.{lower_str}{higher_str}.MA'] = f'Males {lower_str}{higher_str}'


#correct age range:
def range(age_low, age_high, sex): 
    labels = {}
    
    labels_test1 = {}
    age_floor_lessthan_25(0, 24, labels_test1, 'males')
    assert 'SP.POP.AG00.MA.IN' in labels_test1 and 'SP.POP.AG24.MA.IN' in labels_test1, "Failed to retrieve data for ages < 25"

    labels_test2 = {}
    age_floor_greaterthan_25(25, 39, labels_test2, 'females')
    assert 'SP.POP.2529.FE' in labels_test2 and 'SP.POP.3539.FE' in labels_test2, "Failed to retrieve data for ages >= 25"

    #age range [0,25]
    if age_high < 25:
        age_floor_lessthan_25(age_low, age_high, labels, sex)
    #age range [25, +]
    elif age_low >= 25:
        age_floor_greaterthan_25(age_low, age_high, labels, sex)
    #age range [0, 25+]
    else:
        age_floor_lessthan_25(age_low, 24, labels, sex)
        age_floor_greaterthan_25(25, age_high, labels, sex)
        
    return labels



def get_region_df(labels, age_high, sex, place, year):
    df = wbdata.get_dataframe(labels,country = place,parse_dates=True)
    df = df.reset_index()
    df2 = df[df['date'] == f'{year}-01-01']

    #if the age high is >25 and <80 and not a multiple of 5, then take a proportional fraction of the last column
    #example: 27, in range [25, 29] want (27%5 /5)
    #doesn't account for ages 81, 82, 83, etc (difficult to interpolate when so little data on older ages)
    if ((age_high>=25) & (age_high<80) & (age_high%5 != 4)):
        
        population_count = df2.iloc[0, -1]
        display(f'population count: {population_count}')
        proportion = (age_high%5+1) / 5
        df2.iloc[0, -1] = proportion*population_count
        
    return df2
#df = get_df(labels, sex, place, year)
#labels = range(22, 77, 'males')
#df = get_df(labels, 77, 'females', 'COL', 2022)
#df


def population(sex, age_low, age_high, place, year):
    # Error handling for invalid age range
    if age_low > age_high:
        raise ValueError(f"Invalid age range: ({age_low}) < ({age_high}). Please reverse the input age ranges.")

    # Validate `place` is a valid location in wbdata
    ls_countries = wbdata.get_countries()
    country_codes = [country['id'] for country in ls_countries]
    if place not in country_codes:
        raise ValueError(f"Invalid country code: {place}. Please enter a valid country. Call wbdata.get_countries to see the valid list of countries.")


    labels = range(age_low, age_high, sex)
     
    #unit test for age edge cases (if highest age lies in an interval)
    tlabels = {'SP.POP.2529.MA': 'Males 25-29'}
    df_test = get_region_df(tlabels, 27, sex, place, year)
    assert df_test.iloc[0, -1] <= df_test.iloc[0, 1], "Population proportion adjustment error!"
    
    df = get_region_df(labels, age_high, sex, place, year)
    df.drop('date', axis = 1, inplace=True)
    df['total pop in age range'] = df.sum(axis=1)
    total = df.iloc[0]['total pop in age range']
    display(f'In {year}, the number of {sex} between ages {age_low} to {age_high} living in {place} was approximately {total}')
    return df

#df_test = population('males', 0, 100, 'COL', 2000)
#assert df_test.iloc[0]['total pop in age range'] > 1e9 / 2, "Too few males in world population!"

population('males', 0, 99, 'WLD', 2000)
#df_test
# Out:
# 'population count: 256111683.0'
# 'In 2000, the number of males between ages 0 to 99 living in WLD was approximately 1572604973.0'
#    Males 00 Males 01 Males 02 Males 03 Males 04 Males 05 Males 06 Males 07  \
# 23     None     None     None     None     None     None     None     None
#
#    Males 08 Males 09  ...   Males 4044   Males 4549   Males 5054   Males 5559  \
# 23     None     None  ...  188272543.0  166466275.0  131771282.0  102086084.0
#
#     Males 6064  Males 6569  Males 7074  Males 7579  Males 80UP  \
# 23  89361676.0  70844762.0  52502740.0  32593816.0  24774935.0
#
#    total pop in age range
# 23           1572604973.0
#
# [1 rows x 38 columns]

# %% [markdown]
# ## [B] Population DataFrames
# This function returns a pandas DataFrame indexed by Region or Country and Year, with columns giving counts of people in different age-sex groups. For the means of Team Malthus' project focus, this function was designed to produce specifics for **only** regions/countries we are focussing on: the countries directly targeted impacted by Operation Condor.

# %%
#wbdata.get_countries()

# %%
condor_countries = {'ARG': 'Argentina', 'BOL': 'Bolivia', 'BRA': 'Brazil', 'CHL': 'Chile', 'ECU': 'Ecuador', 'CLA':'Latin America and the Caribbean (IFC classification)', 'WLD' :"World"}
#labels = range(22, 77, 'females')
#df = get_df(labels, 77, 'females', 'COL', 2022)
#df


def get_region_df(age_low, age_high, sex, place, year):
    labels = range(age_low, age_high, sex)
    df = wbdata.get_dataframe(labels,country = place,parse_dates=True)
    df = df.reset_index()
    df2 = df[df['date'] == f'{year}-01-01']
    df2['date'] = year
    #if the age high is >25 and <80 and not a multiple of 5, then take a proportional fraction of the last column
    #example: 27, in range [25, 29] want (27%5 /5)
    if ((age_high>=25) & (age_high<80) & (age_high%5 != 4)):
        population_count = df2.iloc[0, -1]
        display(f'population count: {population_count}')
        proportion = (age_high%5+1) / 5
        df2.iloc[0, -1] = proportion*population_count
        
        
    return df2

get_region_df(22, 77, 'females',condor_countries, 2021)
# Out:
# /tmp/ipykernel_76/1665431826.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['date'] = year
# 'population count: 602985.0'
#        country  date  Females 22  Females 23  Females 24  Females 2529  \
# 2    Argentina  2021    340990.0    339364.5    341034.0     1727965.0
# 66     Bolivia  2021    109809.5    108289.5    107373.5      518258.0
# 130     Brazil  2021   1649095.0   1655825.0   1646923.0     8105921.0
# 194      Chile  2021    140459.5    145160.0    149702.0      792156.0
# 258    Ecuador  2021    155491.5    155337.5    155166.0      755239.0
# 322      World  2021         NaN         NaN         NaN   290638670.0
#
#      Females 3034  Females 3539  Females 4044  Females 4549  Females 5054  \
# 2       1651617.0     1583375.0     1548702.0     1372580.0     1183031.0
# 66       469786.0      400557.0      349190.0      297321.0      251647.0
# 130     8299446.0     8539224.0     8027939.0     7135873.0     6449326.0
# 194      795033.0      725313.0      675065.0      649398.0      629116.0
# 258      701586.0      648686.0      574585.0      505627.0      442048.0
# 322   296697604.0   274546997.0   246000086.0   234930861.0   223923211.0
#
#      Females 5559  Females 6064  Females 6569  Females 7074  Females 7579
# 2       1095091.0     1017473.0      914976.0      777595.0      361791.0
# 66       210244.0      169351.0      128503.0       96082.0       68510.0
# 130     6076687.0     5236762.0     4186711.0     3107121.0     2055915.0
# 194      586850.0      520887.0      436213.0      342926.0      236452.0
# 258      377253.0      313465.0      256287.0      198079.0      137218.0
# 322   202156613.0   165292891.0   144946891.0   108698089.0    71377606.0
