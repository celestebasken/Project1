# %%
# %pip install wbdata
import math
import numpy as np
import wbdata
# Out:
# Collecting wbdata
#   Using cached wbdata-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting appdirs<2.0,>=1.4 (from wbdata)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting backoff<3.0.0,>=2.2.1 (from wbdata)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: cachetools<6.0.0,>=5.3.2 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.5.1)
# Collecting dateparser<2.0.0,>=1.2.0 (from wbdata)
#   Using cached dateparser-1.2.0-py2.py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: decorator<6.0.0,>=5.1.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3.0,>=2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.32.3)
# Collecting shelved-cache<0.4.0,>=0.3.1 (from wbdata)
#   Using cached shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting tabulate<0.9.0,>=0.8.5 (from wbdata)
#   Using cached tabulate-0.8.10-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: python-dateutil in /srv/conda/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz in /srv/conda/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2024.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /srv/conda/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2024.11.6)
# Collecting tzlocal (from dateparser<2.0.0,>=1.2.0->wbdata)
#   Using cached tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3.0,>=2.0->wbdata) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil->dateparser<2.0.0,>=1.2.0->wbdata) (1.17.0)
# Using cached wbdata-1.0.0-py3-none-any.whl (18 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
# Using cached shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Using cached tabulate-0.8.10-py3-none-any.whl (29 kB)
# Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# Installing collected packages: appdirs, tzlocal, tabulate, shelved-cache, backoff, dateparser, wbdata
# Successfully installed appdirs-1.4.4 backoff-2.2.1 dateparser-1.2.0 shelved-cache-0.3.1 tabulate-0.8.10 tzlocal-5.2 wbdata-1.0.0
# Note: you may need to restart the kernel to use updated packages.
# Key '6203700015424887885' not in persistent cache.
# Key '6911766142455486187' not in persistent cache.
# Key '2676740241337915329' not in persistent cache.
# Key '-2904060488198345795' not in persistent cache.
# Key '-7139086389315916653' not in persistent cache.
# Key '-6431020262285318351' not in persistent cache.
# Key '628448036318391450' not in persistent cache.
# Key '-940738566167919236' not in persistent cache.
# Key '-323578369819849627' not in persistent cache.
# Key '-4467698340254891792' not in persistent cache.
# Key '6214133935530923207' not in persistent cache.
# Key '2422124671357684475' not in persistent cache.
# Key '8957266758358414218' not in persistent cache.
# Key '9120598240225211488' not in persistent cache.
# Key '-6646867524884226980' not in persistent cache.
# Key '-6392630112334901017' not in persistent cache.
# Key '-3127798010336342711' not in persistent cache.
# Key '7157558886733313733' not in persistent cache.
# Key '7320890368600111003' not in persistent cache.
# Key '3630599112646341177' not in persistent cache.
# Key '-7606784190561556344' not in persistent cache.
# Key '-6185227518007490805' not in persistent cache.
# Key '1024133252494163290' not in persistent cache.
# Key '-2666158003459606536' not in persistent cache.
# Key '8791667678128471393' not in persistent cache.
# Key '176451787007303882' not in persistent cache.
# Key '3441283889005862188' not in persistent cache.
# Key '3695521301555188151' not in persistent cache.
# Key '6785410714503667142' not in persistent cache.
# Key '2993401450330428410' not in persistent cache.
# Key '-4519843153394025335' not in persistent cache.
# Key '-8754869054511596193' not in persistent cache.
# Key '-6075590745911483045' not in persistent cache.
# Key '-5821353333362157082' not in persistent cache.
# Key '-2556521231363598776' not in persistent cache.
# Key '7728835665706057668' not in persistent cache.
# Key '7892167147572854938' not in persistent cache.
# Key '4201875891619085112' not in persistent cache.
# Key '-7035507411588812409' not in persistent cache.
# Key '-5613950739034746870' not in persistent cache.
# Key '1595410031466907225' not in persistent cache.
# Key '-2094881224486862601' not in persistent cache.
# Key '-9083799616608336288' not in persistent cache.
# Key '747728565980047817' not in persistent cache.
# Key '8410918050962974251' not in persistent cache.
# Key '4266798080527932086' not in persistent cache.
# Key '6922708199459516878' not in persistent cache.
# Key '-3915330353348578679' not in persistent cache.
# Key '7018169116636519192' not in persistent cache.
# Key '-8617571569555746457' not in persistent cache.
# Key '5462421524119061482' not in persistent cache.
# Key '5716658936668387445' not in persistent cache.
# Key '8981491038666945751' not in persistent cache.
# Key '5218461245011418707' not in persistent cache.
# Key '8029464632528704674' not in persistent cache.
# Key '4339173376574934848' not in persistent cache.
# Key '4502504858441732118' not in persistent cache.
# Key '5924061530995797657' not in persistent cache.
# Key '-5313321772212099864' not in persistent cache.
# Key '-9003613028165869690' not in persistent cache.
# Key '2454212653422208239' not in persistent cache.
# Key '-6161003237698959272' not in persistent cache.
# Key '1502186247283967162' not in persistent cache.
# Key '-2641933723151075003' not in persistent cache.
# Key '-6000467378530803602' not in persistent cache.
# Key '8654267431005509282' not in persistent cache.
# Key '-5905006461353801288' not in persistent cache.
# Key '-3094003073836515321' not in persistent cache.
# Key '-7460754053871258998' not in persistent cache.
# Key '-7206516641321933035' not in persistent cache.
# Key '-3941684539323374729' not in persistent cache.
# Key '6343672357746281715' not in persistent cache.
# Key '-4893710945461615806' not in persistent cache.
# Key '-8584002201415385632' not in persistent cache.
# Key '-8420670719548588362' not in persistent cache.
# Key '46915241640334002' not in persistent cache.
# Key '210246723507131272' not in persistent cache.
# Key '-3480044532446638554' not in persistent cache.
# Key '7977781149141439375' not in persistent cache.
# Key '-637434741979728136' not in persistent cache.
# Key '7025754743003198298' not in persistent cache.
# Key '2881634772568156133' not in persistent cache.
# Key '-4643132781922276802' not in persistent cache.
# Key '-8435142046095515534' not in persistent cache.
# Key '-1899999959094785791' not in persistent cache.
# Key '-1736668477227988521' not in persistent cache.
# Key '942609831372124627' not in persistent cache.
# Key '1196847243921450590' not in persistent cache.
# Key '-2584349942714847929' not in persistent cache.
# Key '-3699707830719886276' not in persistent cache.
# Key '-3536376348853089006' not in persistent cache.
# Key '-7226667604806858832' not in persistent cache.
# Key '-17306834305204737' not in persistent cache.
# Key '1404249838248860802' not in persistent cache.
# Key '8613610608750514897' not in persistent cache.
# Key '4923319352796745071' not in persistent cache.
# Key '-2065599039324728616' not in persistent cache.
# Key '7765929143263655489' not in persistent cache.
# Key '-7415982828447337821' not in persistent cache.
# Key '4238969369176682933' not in persistent cache.
# Key '-8665691218456012269' not in persistent cache.
# Key '3156103334657988474' not in persistent cache.
# Key '-6002535504695110965' not in persistent cache.
# Key '1606170016206345094' not in persistent cache.
# Key '8141312103207074837' not in persistent cache.
# Key '-3096071200000822684' not in persistent cache.
# Key '-7462822180035566361' not in persistent cache.
# Key '6839801923238943090' not in persistent cache.
# Key '-3943752665487682092' not in persistent cache.
# Key '6341604231581974352' not in persistent cache.
# Key '-4895779071625923169' not in persistent cache.
# Key '-8586070327579692995' not in persistent cache.
# Key '-8422738845712895725' not in persistent cache.
# Key '-7001182173158830186' not in persistent cache.
# Key '208178597342823909' not in persistent cache.
# Key '-3482112658610945917' not in persistent cache.
# Key '3577355639992763884' not in persistent cache.
# Key '-639502868144035499' not in persistent cache.
# Key '2625329233854522807' not in persistent cache.
# Key '2879566646403848770' not in persistent cache.
# Key '5096943582355700089' not in persistent cache.
# Key '5703291701166829485' not in persistent cache.
# Key '5192404499532702403' not in persistent cache.
# Key '8003407887049988370' not in persistent cache.
# Key '3636656907015244693' not in persistent cache.
# Key '3890894319564570656' not in persistent cache.
# Key '7155726421563128962' not in persistent cache.
# Key '3392696627907601918' not in persistent cache.
# Key '6203700015424887885' not in persistent cache.
# Key '6911766142455486187' not in persistent cache.
# Key '2676740241337915329' not in persistent cache.
# Key '-2904060488198345795' not in persistent cache.
# Key '-7139086389315916653' not in persistent cache.
# Key '-6431020262285318351' not in persistent cache.
# Key '628448036318391450' not in persistent cache.
# Key '-940738566167919236' not in persistent cache.
# Key '-323578369819849627' not in persistent cache.
# Key '-4467698340254891792' not in persistent cache.
# Key '6214133935530923207' not in persistent cache.
# Key '2422124671357684475' not in persistent cache.
# Key '8957266758358414218' not in persistent cache.
# Key '9120598240225211488' not in persistent cache.
# Key '-6646867524884226980' not in persistent cache.
# Key '-6392630112334901017' not in persistent cache.
# Key '-3127798010336342711' not in persistent cache.
# Key '7157558886733313733' not in persistent cache.
# Key '7320890368600111003' not in persistent cache.
# Key '3630599112646341177' not in persistent cache.
# Key '-7606784190561556344' not in persistent cache.
# Key '-6185227518007490805' not in persistent cache.
# Key '1024133252494163290' not in persistent cache.
# Key '-2666158003459606536' not in persistent cache.
# Key '8791667678128471393' not in persistent cache.
# Key '176451787007303882' not in persistent cache.
# Key '3441283889005862188' not in persistent cache.
# Key '3695521301555188151' not in persistent cache.
# Key '6785410714503667142' not in persistent cache.
# Key '2993401450330428410' not in persistent cache.
# Key '-4519843153394025335' not in persistent cache.
# Key '-8754869054511596193' not in persistent cache.
# Key '-6075590745911483045' not in persistent cache.
# Key '-5217739987471285343' not in persistent cache.
# Key '4613788195117098762' not in persistent cache.
# Key '5230948391465168371' not in persistent cache.
# Key '1086828421030126206' not in persistent cache.
# Key '7314980799620141771' not in persistent cache.
# Key '6964797893955379305' not in persistent cache.
# Key '9040998686674975059' not in persistent cache.
# Key '8798775038983667161' not in persistent cache.
# Key '4495884806772464098' not in persistent cache.
# Key '-5959516265518517182' not in persistent cache.
# Key '-4622171746946153994' not in persistent cache.
# Key '5763564798786157827' not in persistent cache.
# Key '-2590742819375257014' not in persistent cache.
# Key '-3071901244713468579' not in persistent cache.
# Key '-7537393896721339572' not in persistent cache.
# Key '4652734488409263360' not in persistent cache.
# Key '-2624644688758103260' not in persistent cache.
# Key '6744520886952670915' not in persistent cache.
# Key '-6920803157190494018' not in persistent cache.
# Key '3099997805653597610' not in persistent cache.
# Key '7566276099579335516' not in persistent cache.
# Key '618790385846868582' not in persistent cache.
# Key '6613163129016888418' not in persistent cache.
# Key '-1908160901668266569' not in persistent cache.
# Key '-6342206566628098229' not in persistent cache.
# Key '-6540249340654445932' not in persistent cache.
# Key '6804172668190945949' not in persistent cache.
# Key '7053246915556047296' not in persistent cache.
# Key '-8778794572079998198' not in persistent cache.
# Key '-1010873504686252127' not in persistent cache.
# Key '-1941373682466951224' not in persistent cache.
# Key '987769796938182994' not in persistent cache.
# Key '7323347340671372839' not in persistent cache.
# Key '6765406113906175882' not in persistent cache.
# Key '8475694381775684456' not in persistent cache.
# Key '5406608395378312483' not in persistent cache.
# Key '-7783278823550309996' not in persistent cache.
# Key '4088106771576080452' not in persistent cache.
# Key '-7671946944216855046' not in persistent cache.
# Key '-502445546959963813' not in persistent cache.
# Key '4898081093506602301' not in persistent cache.
# Key '-6725856779366182801' not in persistent cache.
# Key '5942511651164866365' not in persistent cache.
# Key '-7722727616412680146' not in persistent cache.
# Key '-3095533138620559393' not in persistent cache.
# Key '4632893689680559844' not in persistent cache.
# Key '-2629771222838787704' not in persistent cache.
# Key '-1305010708717975809' not in persistent cache.
# Key '-3638187685005025660' not in persistent cache.
# Key '-5708688777203020431' not in persistent cache.
# Key '8953345800211167288' not in persistent cache.
# Key '7510920248247762013' not in persistent cache.
# Key '2592734037493293787' not in persistent cache.
# Key '-5839258768785096567' not in persistent cache.
# Key '6068676594376395171' not in persistent cache.
# Key '-6198596713643233087' not in persistent cache.
# Key '8057300078972122301' not in persistent cache.
# Key '1326510295980508799' not in persistent cache.
# Key '-685618026900216519' not in persistent cache.
# Key '-2603387160907508812' not in persistent cache.
# Key '215510799220857361' not in persistent cache.
# Key '3808459517481291719' not in persistent cache.
# Key '6413608138750120282' not in persistent cache.
# Key '726042973650840945' not in persistent cache.
# Key '7311417265076570176' not in persistent cache.
# Key '-2930259643737186165' not in persistent cache.
# Key '7520655423725319589' not in persistent cache.
# Key '27231174643136303' not in persistent cache.
# Key '3413313121747988500' not in persistent cache.
# Key '1564380486190626150' not in persistent cache.
# Key '5535787725125165696' not in persistent cache.
# Key '-8778146346582244356' not in persistent cache.
# Key '2523185704703689876' not in persistent cache.
# Key '4937693129347825616' not in persistent cache.
# Key '-2730646248007164504' not in persistent cache.
# Key '-648198321588618677' not in persistent cache.
# Key '6470782787748445273' not in persistent cache.
# Key '-469726792844921204' not in persistent cache.
# Key '-2291016976847689100' not in persistent cache.
# Key '-1521983176500284549' not in persistent cache.
# Key '-831758071387587716' not in persistent cache.
# Key '-3095578545904494114' not in persistent cache.
# Key '6096648153539990977' not in persistent cache.
# Key '1799266133062477006' not in persistent cache.
# Key '1013123234937514238' not in persistent cache.
# Key '2007232027826786028' not in persistent cache.
# Key '2743920981887914012' not in persistent cache.
# Key '4592820017267324473' not in persistent cache.
# Key '165506375292450833' not in persistent cache.
# Key '697816706671853534' not in persistent cache.
# Key '1862611160142851692' not in persistent cache.
# Key '-8256562520210310123' not in persistent cache.
# Key '-5020228815523048803' not in persistent cache.
# Key '-5119861891387053609' not in persistent cache.
# Key '-8769716598330590843' not in persistent cache.
# Key '-1662064196555671903' not in persistent cache.
# Key '325496869256914235' not in persistent cache.
# Key '7794820168259221581' not in persistent cache.
# Key '-3035962134978544186' not in persistent cache.
# Key '-1249421221200293111' not in persistent cache.
# Key '9194909521118739112' not in persistent cache.
# Key '7542394839411524568' not in persistent cache.
# Key '3750385575238285836' not in persistent cache.
# Key '-8161216411470536037' not in persistent cache.
# Key '-7997884929603738767' not in persistent cache.
# Key '-5318606621003625619' not in persistent cache.
# Key '-5064369208454299656' not in persistent cache.
# Key '-1799537106455741350' not in persistent cache.
# Key '8485819790613915094' not in persistent cache.
# Key '8649151272480712364' not in persistent cache.
# Key '4958860016526942538' not in persistent cache.
# Key '-6278523286680954983' not in persistent cache.
# Key '-4856966614126889444' not in persistent cache.
# Key '2352394156374764651' not in persistent cache.
# Key '-1337897099579005175' not in persistent cache.
# Key '-8326815491700478862' not in persistent cache.
# Key '1504712690887905243' not in persistent cache.
# Key '9167902175870831677' not in persistent cache.
# Key '5023782205435789512' not in persistent cache.
# Key '-5419994317472455681' not in persistent cache.
# Key '-9212003581645694413' not in persistent cache.
# Key '-2676861494644964670' not in persistent cache.
# Key '-6911887395762535528' not in persistent cache.
# Key '165748295821945748' not in persistent cache.
# Key '-3978371674613096417' not in persistent cache.
# Key '-7759568861249394936' not in persistent cache.
# Key '-4476569366270065155' not in persistent cache.
# Key '-8711595267387636013' not in persistent cache.
# Key '-8003529140357037711' not in persistent cache.
# Key '-5192525752839751744' not in persistent cache.
# Key '627388302698681923' not in persistent cache.
# Key '3438391690215967890' not in persistent cache.
# Key '4146457817246566192' not in persistent cache.
# Key '-7240817957859275623' not in persistent cache.
# Key '2590710224729108482' not in persistent cache.
# Key '-8192844363997516700' not in persistent cache.
# Key '-936249549357864074' not in persistent cache.
# Key '-3802034911271830043' not in persistent cache.
# Key '-7594044175445068775' not in persistent cache.
# Key '-8104931377079195857' not in persistent cache.
# Key '-895570606577541762' not in persistent cache.
# Key '1783707702022571386' not in persistent cache.
# Key '-5008084174062959476' not in persistent cache.
# Key '-1743252072064401170' not in persistent cache.
# Key '8542104825005255274' not in persistent cache.
# Key '-2695278478202642247' not in persistent cache.
# Key '-6385569734156412073' not in persistent cache.
# Key '823791036345242022' not in persistent cache.
# Key '2245347708899307561' not in persistent cache.
# Key '2408679190766104831' not in persistent cache.
# Key '-1281612065187664995' not in persistent cache.
# Key '-1224501168674281857' not in persistent cache.
# Key '8607027013914102248' not in persistent cache.
# Key '-9222556863447379759' not in persistent cache.
# Key '5080067239827129692' not in persistent cache.
# Key '4885742476781473758' not in persistent cache.
# Key '1093733212608235026' not in persistent cache.
# Key '582846010974107944' not in persistent cache.
# Key '7792206781475762039' not in persistent cache.
# Key '-7975258983633676429' not in persistent cache.
# Key '3679693213990344325' not in persistent cache.
# Key '6944525315988902631' not in persistent cache.
# Key '-1216861860650992541' not in persistent cache.
# Key '5992498909850661554' not in persistent cache.
# Key '2302207653896891728' not in persistent cache.
# Key '-8935175649311005793' not in persistent cache.
# Key '-7513618976756940254' not in persistent cache.
# Key '-7350287494890142984' not in persistent cache.
# Key '7406165322865638806' not in persistent cache.
# Key '417246930744165119' not in persistent cache.
# Key '-1151939671742145567' not in persistent cache.
# Key '-534779475394075958' not in persistent cache.
# Key '-4678899445829118123' not in persistent cache.
# Key '4761587339862073038' not in persistent cache.
# Key '-5727299552377780646' not in persistent cache.
# Key '7458906349930302807' not in persistent cache.
# Key '7157214085411920485' not in persistent cache.
# Key '-9128737564481810715' not in persistent cache.
# Key '7984811642672695561' not in persistent cache.
# Key '-380283508371443019' not in persistent cache.
# Key '-281590891106089718' not in persistent cache.
# Key '4134484800224326370' not in persistent cache.
# Key '2063539905599540456' not in persistent cache.
# Key '-7524344224982201195' not in persistent cache.
# Key '-5489557018113061716' not in persistent cache.
# Key '-2047805153634688507' not in persistent cache.
# Key '-7330919891501108313' not in persistent cache.
# Key '1657707803526776771' not in persistent cache.
# Key '-7242037739697586621' not in persistent cache.
# Key '-2698878790343115836' not in persistent cache.
# Key '1810631093708058796' not in persistent cache.
# Key '-462567625830277273' not in persistent cache.
# Key '5898721798380054843' not in persistent cache.
# Key '1011227535167386009' not in persistent cache.
# Key '-7917407950439929951' not in persistent cache.
# Key '-8299843600389076796' not in persistent cache.
# Key '-241096336575978357' not in persistent cache.
# Key '-503301640272357935' not in persistent cache.
# Key '-8901308403751843349' not in persistent cache.
# Key '-3241237671946283235' not in persistent cache.
# Key '-5232294722043071871' not in persistent cache.
# Key '6180379682356351277' not in persistent cache.
# Key '-7003794434456494453' not in persistent cache.
# Key '5155694260796854856' not in persistent cache.
# Key '-5297897952431600328' not in persistent cache.
# Key '-2424887624854194100' not in persistent cache.
# Key '-2127443541417100256' not in persistent cache.
# Key '-3360642998808832303' not in persistent cache.
# Key '-7633213728327342507' not in persistent cache.
# Key '3184985037076273085' not in persistent cache.
# Key '-4902635968683408926' not in persistent cache.
# Key '-3452266294209644425' not in persistent cache.
# Key '-5387684681571128192' not in persistent cache.
# Key '5600658614839886672' not in persistent cache.
# Key '283510074116195526' not in persistent cache.
# Key '5120411973023153468' not in persistent cache.
# Key '-6827913569319133133' not in persistent cache.
# Key '-8653895785552520890' not in persistent cache.
# Key '-3290614330005024755' not in persistent cache.
# Key '-9066144982231947043' not in persistent cache.
# Key '6924718669242376535' not in persistent cache.
# Key '-6525170781855342500' not in persistent cache.
# Key '-3037031526249819366' not in persistent cache.
# Key '2475560589968168021' not in persistent cache.
# Key '-4903504886322734333' not in persistent cache.
# Key '7632691614412783815' not in persistent cache.
# Key '-7115539216766824882' not in persistent cache.
# Key '-1277904148664741798' not in persistent cache.
# Key '5164102791944532667' not in persistent cache.
# Key '-8079444574534262817' not in persistent cache.
# Key '3795298559402820060' not in persistent cache.
# Key '-4320033717859671186' not in persistent cache.
# Key '-4109040875494422015' not in persistent cache.
# Key '-4781641368201560365' not in persistent cache.
# Key '-2656649734236531746' not in persistent cache.
# Key '290790976973823024' not in persistent cache.
# Key '8114872151233637708' not in persistent cache.
# Key '3875113254140600876' not in persistent cache.
# Key '-6182905421161509585' not in persistent cache.
# Key '-3260312347199502668' not in persistent cache.
# Key '-8773272656733750780' not in persistent cache.
# Key '3232144582596795753' not in persistent cache.
# Key '63891036057691474' not in persistent cache.
# Key '1295289649137325335' not in persistent cache.
# Key '-6150064760921084837' not in persistent cache.
# Key '4882190171099860811' not in persistent cache.
# Key '-2389649996077158528' not in persistent cache.
# Key '-6611867435367817855' not in persistent cache.
# Key '5442830121370089947' not in persistent cache.
# Key '-8759818941021759336' not in persistent cache.
# Key '1046961676273751833' not in persistent cache.
# Key '5528585259368495047' not in persistent cache.
# Key '-5027325824057724649' not in persistent cache.
# Key '3816273929526804486' not in persistent cache.
# Key '-2425276910336783155' not in persistent cache.
# Key '-7169061978547448021' not in persistent cache.
# Key '-6023235422882130086' not in persistent cache.
# Key '2041699203390056711' not in persistent cache.
# Key '-441670054875993957' not in persistent cache.
# Key '6739407326412936383' not in persistent cache.
# Key '5013822514738004058' not in persistent cache.
# Key '-1718495420210862902' not in persistent cache.
# Key '3107202759618690769' not in persistent cache.
# Key '-6923153823143180827' not in persistent cache.
# Key '894282715701420963' not in persistent cache.
# Key '-8684220895657695604' not in persistent cache.
# Key '8362847550522175261' not in persistent cache.
# Key '8616289307116892937' not in persistent cache.
# Key '-7480584574945654215' not in persistent cache.
# Key '-3720921230377320576' not in persistent cache.
# Key '3199914028287725755' not in persistent cache.
# Key '-6861558612302893232' not in persistent cache.
# Key '8962024746231453971' not in persistent cache.
# Key '3948603657551841625' not in persistent cache.
# Key '-34267182525450805' not in persistent cache.
# Key '-465267860428293434' not in persistent cache.
# Key '2785760888417391343' not in persistent cache.
# Key '-6069049287997926478' not in persistent cache.
# Key '-6820252137370759581' not in persistent cache.
# Key '-5926991473726245809' not in persistent cache.
# Key '8508570366463844717' not in persistent cache.
# Key '8228466541878870825' not in persistent cache.
# Key '914800237701203736' not in persistent cache.
# Key '-951177244130039049' not in persistent cache.
# Key '2439564283373871200' not in persistent cache.
# Key '-8392112886807150496' not in persistent cache.
# Key '-5867201386938630335' not in persistent cache.
# Key '-153790633334413037' not in persistent cache.
# Key '2743608719945905435' not in persistent cache.
# Key '697816706671853534' not in persistent cache.
# Key '-8256562520210310123' not in persistent cache.
# Key '7726960029180166042' not in persistent cache.
# Key '-917064101502049978' not in persistent cache.
# Key '1564380486190626150' not in persistent cache.
# Key '5535787725125165696' not in persistent cache.
# Key '-8778146346582244356' not in persistent cache.
# Key '2523185704703689876' not in persistent cache.
# Key '4937693129347825616' not in persistent cache.
# Key '-2730646248007164504' not in persistent cache.
# Key '-5548941850762942506' not in persistent cache.
# Key '-3370813000475351121' not in persistent cache.
# Key '3002786161647814085' not in persistent cache.
# Key '-8680368482827041663' not in persistent cache.
# Key '7099828924531152109' not in persistent cache.
# Key '-8420238231864674773' not in persistent cache.
# Key '-8107331980626708473' not in persistent cache.
# Key '-7689412622639750337' not in persistent cache.
# Key '2031768208641529021' not in persistent cache.
# Key '-6012853298813501680' not in persistent cache.
# Key '432624116327025280' not in persistent cache.
# Key '-2395325543557774005' not in persistent cache.
# Key '-204976377293182705' not in persistent cache.
# Key '3306502291589845565' not in persistent cache.
# Key '-2421112809237361876' not in persistent cache.
# Key '1862611160142851692' not in persistent cache.
# Key '-5020228815523048803' not in persistent cache.
# Key '-4135954157318484558' not in persistent cache.
# Key '-778442020508654309' not in persistent cache.
# Key '6203700015424887885' not in persistent cache.
# Key '6911766142455486187' not in persistent cache.
# Key '2676740241337915329' not in persistent cache.
# Key '-2904060488198345795' not in persistent cache.
# Key '-7139086389315916653' not in persistent cache.
# Key '-6431020262285318351' not in persistent cache.
# Key '628448036318391450' not in persistent cache.
# Key '-940738566167919236' not in persistent cache.
# Key '-323578369819849627' not in persistent cache.
# Key '-4467698340254891792' not in persistent cache.
# Key '6214133935530923207' not in persistent cache.
# Key '2422124671357684475' not in persistent cache.
# Key '8957266758358414218' not in persistent cache.
# Key '9120598240225211488' not in persistent cache.
# Key '-6646867524884226980' not in persistent cache.
# Key '-6392630112334901017' not in persistent cache.
# Key '-3127798010336342711' not in persistent cache.
# Key '7157558886733313733' not in persistent cache.
# Key '7320890368600111003' not in persistent cache.
# Key '3630599112646341177' not in persistent cache.
# Key '-7606784190561556344' not in persistent cache.
# Key '-6185227518007490805' not in persistent cache.
# Key '1024133252494163290' not in persistent cache.
# Key '-2666158003459606536' not in persistent cache.
# Key '8791667678128471393' not in persistent cache.
# Key '176451787007303882' not in persistent cache.
# Key '3441283889005862188' not in persistent cache.
# Key '3695521301555188151' not in persistent cache.
# Key '6785410714503667142' not in persistent cache.
# Key '2993401450330428410' not in persistent cache.
# Key '-4519843153394025335' not in persistent cache.
# Key '-8754869054511596193' not in persistent cache.
# Key '-6075590745911483045' not in persistent cache.
# Key '-5821353333362157082' not in persistent cache.
# Key '-2556521231363598776' not in persistent cache.
# Key '7728835665706057668' not in persistent cache.
# Key '7892167147572854938' not in persistent cache.
# Key '4201875891619085112' not in persistent cache.
# Key '-7035507411588812409' not in persistent cache.
# Key '-5613950739034746870' not in persistent cache.
# Key '1595410031466907225' not in persistent cache.
# Key '-2094881224486862601' not in persistent cache.
# Key '-9083799616608336288' not in persistent cache.
# Key '747728565980047817' not in persistent cache.
# Key '8410918050962974251' not in persistent cache.
# Key '4266798080527932086' not in persistent cache.
# Key '6922708199459516878' not in persistent cache.
# Key '-3915330353348578679' not in persistent cache.
# Key '7018169116636519192' not in persistent cache.
# Key '-8617571569555746457' not in persistent cache.
# Key '5462421524119061482' not in persistent cache.
# Key '5716658936668387445' not in persistent cache.
# Key '8981491038666945751' not in persistent cache.
# Key '5218461245011418707' not in persistent cache.
# Key '8029464632528704674' not in persistent cache.
# Key '4339173376574934848' not in persistent cache.
# Key '4502504858441732118' not in persistent cache.
# Key '5924061530995797657' not in persistent cache.
# Key '-5313321772212099864' not in persistent cache.
# Key '-9003613028165869690' not in persistent cache.
# Key '2454212653422208239' not in persistent cache.
# Key '-6161003237698959272' not in persistent cache.
# Key '1502186247283967162' not in persistent cache.
# Key '-2641933723151075003' not in persistent cache.
# Key '-6000467378530803602' not in persistent cache.
# Key '8654267431005509282' not in persistent cache.
# Key '-5905006461353801288' not in persistent cache.
# Key '-3094003073836515321' not in persistent cache.
# Key '-7460754053871258998' not in persistent cache.
# Key '-7206516641321933035' not in persistent cache.
# Key '-3941684539323374729' not in persistent cache.
# Key '6343672357746281715' not in persistent cache.
# Key '-4893710945461615806' not in persistent cache.
# Key '-8584002201415385632' not in persistent cache.
# Key '-8420670719548588362' not in persistent cache.
# Key '46915241640334002' not in persistent cache.
# Key '210246723507131272' not in persistent cache.
# Key '-3480044532446638554' not in persistent cache.
# Key '7977781149141439375' not in persistent cache.
# Key '-637434741979728136' not in persistent cache.
# Key '7025754743003198298' not in persistent cache.
# Key '2881634772568156133' not in persistent cache.
# Key '-4643132781922276802' not in persistent cache.
# Key '-8435142046095515534' not in persistent cache.
# Key '-1899999959094785791' not in persistent cache.
# Key '-1736668477227988521' not in persistent cache.
# Key '942609831372124627' not in persistent cache.
# Key '1196847243921450590' not in persistent cache.
# Key '-2584349942714847929' not in persistent cache.
# Key '-3699707830719886276' not in persistent cache.
# Key '-3536376348853089006' not in persistent cache.
# Key '-7226667604806858832' not in persistent cache.
# Key '-17306834305204737' not in persistent cache.
# Key '1404249838248860802' not in persistent cache.
# Key '8613610608750514897' not in persistent cache.
# Key '4923319352796745071' not in persistent cache.
# Key '-2065599039324728616' not in persistent cache.
# Key '7765929143263655489' not in persistent cache.
# Key '-7415982828447337821' not in persistent cache.
# Key '4238969369176682933' not in persistent cache.
# Key '-8665691218456012269' not in persistent cache.
# Key '3156103334657988474' not in persistent cache.
# Key '-6002535504695110965' not in persistent cache.
# Key '1606170016206345094' not in persistent cache.
# Key '8141312103207074837' not in persistent cache.
# Key '-3096071200000822684' not in persistent cache.
# Key '-7462822180035566361' not in persistent cache.
# Key '6839801923238943090' not in persistent cache.
# Key '-3943752665487682092' not in persistent cache.
# Key '6341604231581974352' not in persistent cache.
# Key '-4895779071625923169' not in persistent cache.
# Key '-8586070327579692995' not in persistent cache.
# Key '-8422738845712895725' not in persistent cache.
# Key '-7001182173158830186' not in persistent cache.
# Key '208178597342823909' not in persistent cache.
# Key '-3482112658610945917' not in persistent cache.
# Key '3577355639992763884' not in persistent cache.
# Key '-639502868144035499' not in persistent cache.
# Key '2625329233854522807' not in persistent cache.
# Key '2879566646403848770' not in persistent cache.
# Key '5096943582355700089' not in persistent cache.
# Key '5703291701166829485' not in persistent cache.
# Key '5192404499532702403' not in persistent cache.
# Key '8003407887049988370' not in persistent cache.
# Key '3636656907015244693' not in persistent cache.
# Key '3890894319564570656' not in persistent cache.
# Key '7155726421563128962' not in persistent cache.
# Key '3392696627907601918' not in persistent cache.
# Key '6203700015424887885' not in persistent cache.
# Key '6911766142455486187' not in persistent cache.
# Key '2676740241337915329' not in persistent cache.
# Key '-2904060488198345795' not in persistent cache.
# Key '-7139086389315916653' not in persistent cache.
# Key '-6431020262285318351' not in persistent cache.
# Key '628448036318391450' not in persistent cache.
# Key '-940738566167919236' not in persistent cache.
# Key '-323578369819849627' not in persistent cache.
# Key '-4467698340254891792' not in persistent cache.
# Key '6214133935530923207' not in persistent cache.
# Key '2422124671357684475' not in persistent cache.
# Key '8957266758358414218' not in persistent cache.
# Key '9120598240225211488' not in persistent cache.
# Key '-6646867524884226980' not in persistent cache.
# Key '-6392630112334901017' not in persistent cache.
# Key '-3127798010336342711' not in persistent cache.
# Key '7157558886733313733' not in persistent cache.
# Key '7320890368600111003' not in persistent cache.
# Key '3630599112646341177' not in persistent cache.
# Key '-7606784190561556344' not in persistent cache.
# Key '-6185227518007490805' not in persistent cache.
# Key '1024133252494163290' not in persistent cache.
# Key '-2666158003459606536' not in persistent cache.
# Key '8791667678128471393' not in persistent cache.
# Key '176451787007303882' not in persistent cache.
# Key '3441283889005862188' not in persistent cache.
# Key '3695521301555188151' not in persistent cache.
# Key '6785410714503667142' not in persistent cache.
# Key '2993401450330428410' not in persistent cache.
# Key '-4519843153394025335' not in persistent cache.
# Key '-8754869054511596193' not in persistent cache.
# Key '-6075590745911483045' not in persistent cache.
# Key '-5217739987471285343' not in persistent cache.
# Key '4613788195117098762' not in persistent cache.
# Key '5230948391465168371' not in persistent cache.
# Key '1086828421030126206' not in persistent cache.
# Key '7314980799620141771' not in persistent cache.
# Key '6964797893955379305' not in persistent cache.
# Key '9040998686674975059' not in persistent cache.
# Key '8798775038983667161' not in persistent cache.
# Key '4495884806772464098' not in persistent cache.
# Key '-5959516265518517182' not in persistent cache.
# Key '-4622171746946153994' not in persistent cache.
# Key '5763564798786157827' not in persistent cache.
# Key '-2590742819375257014' not in persistent cache.
# Key '-3071901244713468579' not in persistent cache.
# Key '-7537393896721339572' not in persistent cache.
# Key '4652734488409263360' not in persistent cache.
# Key '-2624644688758103260' not in persistent cache.
# Key '6744520886952670915' not in persistent cache.
# Key '-6920803157190494018' not in persistent cache.
# Key '3099997805653597610' not in persistent cache.
# Key '7566276099579335516' not in persistent cache.
# Key '618790385846868582' not in persistent cache.
# Key '6613163129016888418' not in persistent cache.
# Key '-1908160901668266569' not in persistent cache.
# Key '-6342206566628098229' not in persistent cache.
# Key '-6540249340654445932' not in persistent cache.
# Key '6804172668190945949' not in persistent cache.
# Key '7053246915556047296' not in persistent cache.
# Key '-8778794572079998198' not in persistent cache.
# Key '-1010873504686252127' not in persistent cache.
# Key '-1941373682466951224' not in persistent cache.
# Key '987769796938182994' not in persistent cache.
# Key '7323347340671372839' not in persistent cache.
# Key '6765406113906175882' not in persistent cache.
# Key '8475694381775684456' not in persistent cache.
# Key '5406608395378312483' not in persistent cache.
# Key '-7783278823550309996' not in persistent cache.
# Key '4088106771576080452' not in persistent cache.
# Key '-7671946944216855046' not in persistent cache.
# Key '-502445546959963813' not in persistent cache.
# Key '4898081093506602301' not in persistent cache.
# Key '-6725856779366182801' not in persistent cache.
# Key '5942511651164866365' not in persistent cache.
# Key '-7722727616412680146' not in persistent cache.
# Key '-3095533138620559393' not in persistent cache.
# Key '4632893689680559844' not in persistent cache.
# Key '-2629771222838787704' not in persistent cache.
# Key '-1305010708717975809' not in persistent cache.
# Key '-3638187685005025660' not in persistent cache.
# Key '-5708688777203020431' not in persistent cache.
# Key '8953345800211167288' not in persistent cache.
# Key '7510920248247762013' not in persistent cache.
# Key '2592734037493293787' not in persistent cache.
# Key '-5839258768785096567' not in persistent cache.
# Key '6068676594376395171' not in persistent cache.
# Key '-6198596713643233087' not in persistent cache.
# Key '8057300078972122301' not in persistent cache.
# Key '1326510295980508799' not in persistent cache.
# Key '-685618026900216519' not in persistent cache.
# Key '-2603387160907508812' not in persistent cache.
# Key '215510799220857361' not in persistent cache.
# Key '3808459517481291719' not in persistent cache.
# Key '6413608138750120282' not in persistent cache.
# Key '726042973650840945' not in persistent cache.
# Key '7311417265076570176' not in persistent cache.
# Key '-2930259643737186165' not in persistent cache.
# Key '7520655423725319589' not in persistent cache.
# Key '27231174643136303' not in persistent cache.
# Key '3413313121747988500' not in persistent cache.
# Key '1564380486190626150' not in persistent cache.
# Key '5535787725125165696' not in persistent cache.
# Key '-8778146346582244356' not in persistent cache.
# Key '2523185704703689876' not in persistent cache.
# Key '4937693129347825616' not in persistent cache.
# Key '-2730646248007164504' not in persistent cache.
# Key '-648198321588618677' not in persistent cache.
# Key '6470782787748445273' not in persistent cache.
# Key '-469726792844921204' not in persistent cache.
# Key '-2291016976847689100' not in persistent cache.
# Key '-1521983176500284549' not in persistent cache.
# Key '-831758071387587716' not in persistent cache.
# Key '-3095578545904494114' not in persistent cache.
# Key '6096648153539990977' not in persistent cache.
# Key '1799266133062477006' not in persistent cache.
# Key '1013123234937514238' not in persistent cache.
# Key '2007232027826786028' not in persistent cache.
# Key '2743920981887914012' not in persistent cache.
# Key '4592820017267324473' not in persistent cache.
# Key '165506375292450833' not in persistent cache.
# Key '697816706671853534' not in persistent cache.
# Key '1862611160142851692' not in persistent cache.
# Key '-8256562520210310123' not in persistent cache.
# Key '-5020228815523048803' not in persistent cache.
# Key '-5119861891387053609' not in persistent cache.
# Key '-8769716598330590843' not in persistent cache.
# Key '-1662064196555671903' not in persistent cache.
# Key '325496869256914235' not in persistent cache.
# Key '7794820168259221581' not in persistent cache.
# Key '-3035962134978544186' not in persistent cache.
# Key '-1249421221200293111' not in persistent cache.
# Key '9194909521118739112' not in persistent cache.
# Key '7542394839411524568' not in persistent cache.
# Key '3750385575238285836' not in persistent cache.
# Key '-8161216411470536037' not in persistent cache.
# Key '-7997884929603738767' not in persistent cache.
# Key '-5318606621003625619' not in persistent cache.
# Key '-5064369208454299656' not in persistent cache.
# Key '-1799537106455741350' not in persistent cache.
# Key '8485819790613915094' not in persistent cache.
# Key '8649151272480712364' not in persistent cache.
# Key '4958860016526942538' not in persistent cache.
# Key '-6278523286680954983' not in persistent cache.
# Key '-4856966614126889444' not in persistent cache.
# Key '2352394156374764651' not in persistent cache.
# Key '-1337897099579005175' not in persistent cache.
# Key '-8326815491700478862' not in persistent cache.
# Key '1504712690887905243' not in persistent cache.
# Key '9167902175870831677' not in persistent cache.
# Key '5023782205435789512' not in persistent cache.
# Key '-5419994317472455681' not in persistent cache.
# Key '-9212003581645694413' not in persistent cache.
# Key '-2676861494644964670' not in persistent cache.
# Key '-6911887395762535528' not in persistent cache.
# Key '165748295821945748' not in persistent cache.
# Key '-3978371674613096417' not in persistent cache.
# Key '-7759568861249394936' not in persistent cache.
# Key '-4476569366270065155' not in persistent cache.
# Key '-8711595267387636013' not in persistent cache.
# Key '-8003529140357037711' not in persistent cache.
# Key '-5192525752839751744' not in persistent cache.
# Key '627388302698681923' not in persistent cache.
# Key '3438391690215967890' not in persistent cache.
# Key '4146457817246566192' not in persistent cache.
# Key '-7240817957859275623' not in persistent cache.
# Key '2590710224729108482' not in persistent cache.
# Key '-8192844363997516700' not in persistent cache.
# Key '-936249549357864074' not in persistent cache.
# Key '-3802034911271830043' not in persistent cache.
# Key '-7594044175445068775' not in persistent cache.
# Key '-8104931377079195857' not in persistent cache.
# Key '-895570606577541762' not in persistent cache.
# Key '1783707702022571386' not in persistent cache.
# Key '-5008084174062959476' not in persistent cache.
# Key '-1743252072064401170' not in persistent cache.
# Key '8542104825005255274' not in persistent cache.
# Key '-2695278478202642247' not in persistent cache.
# Key '-6385569734156412073' not in persistent cache.
# Key '823791036345242022' not in persistent cache.
# Key '2245347708899307561' not in persistent cache.
# Key '2408679190766104831' not in persistent cache.
# Key '-1281612065187664995' not in persistent cache.
# Key '-1224501168674281857' not in persistent cache.
# Key '8607027013914102248' not in persistent cache.
# Key '-9222556863447379759' not in persistent cache.
# Key '5080067239827129692' not in persistent cache.
# Key '4885742476781473758' not in persistent cache.
# Key '1093733212608235026' not in persistent cache.
# Key '582846010974107944' not in persistent cache.
# Key '7792206781475762039' not in persistent cache.
# Key '-7975258983633676429' not in persistent cache.
# Key '3679693213990344325' not in persistent cache.
# Key '6944525315988902631' not in persistent cache.
# Key '-1216861860650992541' not in persistent cache.
# Key '5992498909850661554' not in persistent cache.
# Key '2302207653896891728' not in persistent cache.
# Key '-8935175649311005793' not in persistent cache.
# Key '-7513618976756940254' not in persistent cache.
# Key '-7350287494890142984' not in persistent cache.
# Key '7406165322865638806' not in persistent cache.
# Key '417246930744165119' not in persistent cache.
# Key '-1151939671742145567' not in persistent cache.
# Key '-534779475394075958' not in persistent cache.
# Key '-4678899445829118123' not in persistent cache.
# Key '4761587339862073038' not in persistent cache.
# Key '-5727299552377780646' not in persistent cache.
# Key '7458906349930302807' not in persistent cache.
# Key '7157214085411920485' not in persistent cache.
# Key '-9128737564481810715' not in persistent cache.
# Key '7984811642672695561' not in persistent cache.
# Key '-380283508371443019' not in persistent cache.
# Key '-281590891106089718' not in persistent cache.
# Key '4134484800224326370' not in persistent cache.
# Key '2063539905599540456' not in persistent cache.
# Key '-7524344224982201195' not in persistent cache.
# Key '-5489557018113061716' not in persistent cache.
# Key '-2047805153634688507' not in persistent cache.
# Key '-7330919891501108313' not in persistent cache.
# Key '1657707803526776771' not in persistent cache.
# Key '-7242037739697586621' not in persistent cache.
# Key '-2698878790343115836' not in persistent cache.
# Key '1810631093708058796' not in persistent cache.
# Key '-462567625830277273' not in persistent cache.
# Key '5898721798380054843' not in persistent cache.
# Key '1011227535167386009' not in persistent cache.
# Key '-7917407950439929951' not in persistent cache.
# Key '-8299843600389076796' not in persistent cache.
# Key '-241096336575978357' not in persistent cache.
# Key '-503301640272357935' not in persistent cache.
# Key '-8901308403751843349' not in persistent cache.
# Key '-3241237671946283235' not in persistent cache.
# Key '-5232294722043071871' not in persistent cache.
# Key '6180379682356351277' not in persistent cache.
# Key '-7003794434456494453' not in persistent cache.
# Key '5155694260796854856' not in persistent cache.
# Key '-5297897952431600328' not in persistent cache.
# Key '-2424887624854194100' not in persistent cache.
# Key '-2127443541417100256' not in persistent cache.
# Key '-3360642998808832303' not in persistent cache.
# Key '-7633213728327342507' not in persistent cache.
# Key '3184985037076273085' not in persistent cache.
# Key '-4902635968683408926' not in persistent cache.
# Key '-3452266294209644425' not in persistent cache.
# Key '-5387684681571128192' not in persistent cache.
# Key '5600658614839886672' not in persistent cache.
# Key '283510074116195526' not in persistent cache.
# Key '5120411973023153468' not in persistent cache.
# Key '-6827913569319133133' not in persistent cache.
# Key '-8653895785552520890' not in persistent cache.
# Key '-3290614330005024755' not in persistent cache.
# Key '-9066144982231947043' not in persistent cache.
# Key '6924718669242376535' not in persistent cache.
# Key '-6525170781855342500' not in persistent cache.
# Key '-3037031526249819366' not in persistent cache.
# Key '2475560589968168021' not in persistent cache.
# Key '-4903504886322734333' not in persistent cache.
# Key '7632691614412783815' not in persistent cache.
# Key '-7115539216766824882' not in persistent cache.
# Key '-1277904148664741798' not in persistent cache.
# Key '5164102791944532667' not in persistent cache.
# Key '-8079444574534262817' not in persistent cache.
# Key '3795298559402820060' not in persistent cache.
# Key '-4320033717859671186' not in persistent cache.
# Key '-4109040875494422015' not in persistent cache.
# Key '-4781641368201560365' not in persistent cache.
# Key '-2656649734236531746' not in persistent cache.
# Key '290790976973823024' not in persistent cache.
# ...
# Key '2523185704703689876' not in persistent cache.
# Key '4937693129347825616' not in persistent cache.
# Key '-2730646248007164504' not in persistent cache.
# Key '-5548941850762942506' not in persistent cache.
# Key '-3370813000475351121' not in persistent cache.
# Key '3002786161647814085' not in persistent cache.
# Key '-8680368482827041663' not in persistent cache.
# Key '7099828924531152109' not in persistent cache.
# Key '-8420238231864674773' not in persistent cache.
# Key '-8107331980626708473' not in persistent cache.
# Key '-7689412622639750337' not in persistent cache.
# Key '2031768208641529021' not in persistent cache.
# Key '-6012853298813501680' not in persistent cache.
# Key '432624116327025280' not in persistent cache.
# Key '-2395325543557774005' not in persistent cache.
# Key '-204976377293182705' not in persistent cache.
# Key '3306502291589845565' not in persistent cache.
# Key '-2421112809237361876' not in persistent cache.
# Key '1862611160142851692' not in persistent cache.
# Key '-5020228815523048803' not in persistent cache.
# Key '-4135954157318484558' not in persistent cache.
# Key '-778442020508654309' not in persistent cache.
# Key '6203700015424887885' not in persistent cache.
# Key '6911766142455486187' not in persistent cache.
# Key '2676740241337915329' not in persistent cache.
# Key '-2904060488198345795' not in persistent cache.
# Key '-7139086389315916653' not in persistent cache.
# Key '-6431020262285318351' not in persistent cache.
# Key '628448036318391450' not in persistent cache.
# Key '-940738566167919236' not in persistent cache.
# Key '-323578369819849627' not in persistent cache.
# Key '-4467698340254891792' not in persistent cache.
# Key '6214133935530923207' not in persistent cache.
# Key '2422124671357684475' not in persistent cache.
# Key '8957266758358414218' not in persistent cache.
# Key '9120598240225211488' not in persistent cache.
# Key '-6646867524884226980' not in persistent cache.
# Key '-6392630112334901017' not in persistent cache.
# Key '-3127798010336342711' not in persistent cache.
# Key '7157558886733313733' not in persistent cache.
# Key '7320890368600111003' not in persistent cache.
# Key '3630599112646341177' not in persistent cache.
# Key '-7606784190561556344' not in persistent cache.
# Key '-6185227518007490805' not in persistent cache.
# Key '1024133252494163290' not in persistent cache.
# Key '-2666158003459606536' not in persistent cache.
# Key '8791667678128471393' not in persistent cache.
# Key '176451787007303882' not in persistent cache.
# Key '3441283889005862188' not in persistent cache.
# Key '3695521301555188151' not in persistent cache.
# Key '6785410714503667142' not in persistent cache.
# Key '2993401450330428410' not in persistent cache.
# Key '-4519843153394025335' not in persistent cache.
# Key '-8754869054511596193' not in persistent cache.
# Key '-6075590745911483045' not in persistent cache.
# Key '-5821353333362157082' not in persistent cache.
# Key '-2556521231363598776' not in persistent cache.
# Key '7728835665706057668' not in persistent cache.
# Key '7892167147572854938' not in persistent cache.
# Key '4201875891619085112' not in persistent cache.
# Key '-7035507411588812409' not in persistent cache.
# Key '-5613950739034746870' not in persistent cache.
# Key '1595410031466907225' not in persistent cache.
# Key '-2094881224486862601' not in persistent cache.
# Key '-9083799616608336288' not in persistent cache.
# Key '747728565980047817' not in persistent cache.
# Key '8410918050962974251' not in persistent cache.
# Key '4266798080527932086' not in persistent cache.
# Key '6922708199459516878' not in persistent cache.
# Key '-3915330353348578679' not in persistent cache.
# Key '7018169116636519192' not in persistent cache.
# Key '-8617571569555746457' not in persistent cache.
# Key '5462421524119061482' not in persistent cache.
# Key '5716658936668387445' not in persistent cache.
# Key '8981491038666945751' not in persistent cache.
# Key '5218461245011418707' not in persistent cache.
# Key '8029464632528704674' not in persistent cache.
# Key '4339173376574934848' not in persistent cache.
# Key '4502504858441732118' not in persistent cache.
# Key '5924061530995797657' not in persistent cache.
# Key '-5313321772212099864' not in persistent cache.
# Key '-9003613028165869690' not in persistent cache.
# Key '2454212653422208239' not in persistent cache.
# Key '-6161003237698959272' not in persistent cache.
# Key '1502186247283967162' not in persistent cache.
# Key '-2641933723151075003' not in persistent cache.
# Key '-6000467378530803602' not in persistent cache.
# Key '8654267431005509282' not in persistent cache.
# Key '-5905006461353801288' not in persistent cache.
# Key '-3094003073836515321' not in persistent cache.
# Key '-7460754053871258998' not in persistent cache.
# Key '-7206516641321933035' not in persistent cache.
# Key '-3941684539323374729' not in persistent cache.
# Key '6343672357746281715' not in persistent cache.
# Key '-4893710945461615806' not in persistent cache.
# Key '-8584002201415385632' not in persistent cache.
# Key '-8420670719548588362' not in persistent cache.
# Key '46915241640334002' not in persistent cache.
# Key '210246723507131272' not in persistent cache.
# Key '-3480044532446638554' not in persistent cache.
# Key '7977781149141439375' not in persistent cache.
# Key '-637434741979728136' not in persistent cache.
# Key '7025754743003198298' not in persistent cache.
# Key '2881634772568156133' not in persistent cache.
# Key '-4643132781922276802' not in persistent cache.
# Key '-8435142046095515534' not in persistent cache.
# Key '-1899999959094785791' not in persistent cache.
# Key '-1736668477227988521' not in persistent cache.
# Key '942609831372124627' not in persistent cache.
# Key '1196847243921450590' not in persistent cache.
# Key '-2584349942714847929' not in persistent cache.
# Key '-3699707830719886276' not in persistent cache.
# Key '-3536376348853089006' not in persistent cache.
# Key '-7226667604806858832' not in persistent cache.
# Key '-17306834305204737' not in persistent cache.
# Key '1404249838248860802' not in persistent cache.
# Key '8613610608750514897' not in persistent cache.
# Key '4923319352796745071' not in persistent cache.
# Key '-2065599039324728616' not in persistent cache.
# Key '7765929143263655489' not in persistent cache.
# Key '-7415982828447337821' not in persistent cache.
# Key '4238969369176682933' not in persistent cache.
# Key '-8665691218456012269' not in persistent cache.
# Key '3156103334657988474' not in persistent cache.
# Key '-6002535504695110965' not in persistent cache.
# Key '1606170016206345094' not in persistent cache.
# Key '8141312103207074837' not in persistent cache.
# Key '-3096071200000822684' not in persistent cache.
# Key '-7462822180035566361' not in persistent cache.
# Key '6839801923238943090' not in persistent cache.
# Key '-3943752665487682092' not in persistent cache.
# Key '6341604231581974352' not in persistent cache.
# Key '-4895779071625923169' not in persistent cache.
# Key '-8586070327579692995' not in persistent cache.
# Key '-8422738845712895725' not in persistent cache.
# Key '-7001182173158830186' not in persistent cache.
# Key '208178597342823909' not in persistent cache.
# Key '-3482112658610945917' not in persistent cache.
# Key '3577355639992763884' not in persistent cache.
# Key '-639502868144035499' not in persistent cache.
# Key '2625329233854522807' not in persistent cache.
# Key '2879566646403848770' not in persistent cache.
# Key '5096943582355700089' not in persistent cache.
# Key '5703291701166829485' not in persistent cache.
# Key '5192404499532702403' not in persistent cache.
# Key '8003407887049988370' not in persistent cache.
# Key '3636656907015244693' not in persistent cache.
# Key '3890894319564570656' not in persistent cache.
# Key '7155726421563128962' not in persistent cache.
# Key '3392696627907601918' not in persistent cache.
# Key '6203700015424887885' not in persistent cache.
# Key '6911766142455486187' not in persistent cache.
# Key '2676740241337915329' not in persistent cache.
# Key '-2904060488198345795' not in persistent cache.
# Key '-7139086389315916653' not in persistent cache.
# Key '-6431020262285318351' not in persistent cache.
# Key '628448036318391450' not in persistent cache.
# Key '-940738566167919236' not in persistent cache.
# Key '-323578369819849627' not in persistent cache.
# Key '-4467698340254891792' not in persistent cache.
# Key '6214133935530923207' not in persistent cache.
# Key '2422124671357684475' not in persistent cache.
# Key '8957266758358414218' not in persistent cache.
# Key '9120598240225211488' not in persistent cache.
# Key '-6646867524884226980' not in persistent cache.
# Key '-6392630112334901017' not in persistent cache.
# Key '-3127798010336342711' not in persistent cache.
# Key '7157558886733313733' not in persistent cache.
# Key '7320890368600111003' not in persistent cache.
# Key '3630599112646341177' not in persistent cache.
# Key '-7606784190561556344' not in persistent cache.
# Key '-6185227518007490805' not in persistent cache.
# Key '1024133252494163290' not in persistent cache.
# Key '-2666158003459606536' not in persistent cache.
# Key '8791667678128471393' not in persistent cache.
# Key '176451787007303882' not in persistent cache.
# Key '3441283889005862188' not in persistent cache.
# Key '3695521301555188151' not in persistent cache.
# Key '6785410714503667142' not in persistent cache.
# Key '2993401450330428410' not in persistent cache.
# Key '-4519843153394025335' not in persistent cache.
# Key '-8754869054511596193' not in persistent cache.
# Key '-6075590745911483045' not in persistent cache.
# Key '-5217739987471285343' not in persistent cache.
# Key '4613788195117098762' not in persistent cache.
# Key '5230948391465168371' not in persistent cache.
# Key '1086828421030126206' not in persistent cache.
# Key '7314980799620141771' not in persistent cache.
# Key '6964797893955379305' not in persistent cache.
# Key '9040998686674975059' not in persistent cache.
# Key '8798775038983667161' not in persistent cache.
# Key '4495884806772464098' not in persistent cache.
# Key '-5959516265518517182' not in persistent cache.
# Key '-4622171746946153994' not in persistent cache.
# Key '5763564798786157827' not in persistent cache.
# Key '-2590742819375257014' not in persistent cache.
# Key '-3071901244713468579' not in persistent cache.
# Key '-7537393896721339572' not in persistent cache.
# Key '4652734488409263360' not in persistent cache.
# Key '-2624644688758103260' not in persistent cache.
# Key '6744520886952670915' not in persistent cache.
# Key '-6920803157190494018' not in persistent cache.
# Key '3099997805653597610' not in persistent cache.
# Key '7566276099579335516' not in persistent cache.
# Key '618790385846868582' not in persistent cache.
# Key '6613163129016888418' not in persistent cache.
# Key '-1908160901668266569' not in persistent cache.
# Key '-6342206566628098229' not in persistent cache.
# Key '-6540249340654445932' not in persistent cache.
# Key '6804172668190945949' not in persistent cache.
# Key '7053246915556047296' not in persistent cache.
# Key '-8778794572079998198' not in persistent cache.
# Key '-1010873504686252127' not in persistent cache.
# Key '-1941373682466951224' not in persistent cache.
# Key '987769796938182994' not in persistent cache.
# Key '7323347340671372839' not in persistent cache.
# Key '6765406113906175882' not in persistent cache.
# Key '8475694381775684456' not in persistent cache.
# Key '5406608395378312483' not in persistent cache.
# Key '-7783278823550309996' not in persistent cache.
# Key '4088106771576080452' not in persistent cache.
# Key '-7671946944216855046' not in persistent cache.
# Key '-502445546959963813' not in persistent cache.
# Key '4898081093506602301' not in persistent cache.
# Key '-6725856779366182801' not in persistent cache.
# Key '5942511651164866365' not in persistent cache.
# Key '-7722727616412680146' not in persistent cache.
# Key '-3095533138620559393' not in persistent cache.
# Key '4632893689680559844' not in persistent cache.
# Key '-2629771222838787704' not in persistent cache.
# Key '-1305010708717975809' not in persistent cache.
# Key '-3638187685005025660' not in persistent cache.
# Key '-5708688777203020431' not in persistent cache.
# Key '8953345800211167288' not in persistent cache.
# Key '7510920248247762013' not in persistent cache.
# Key '2592734037493293787' not in persistent cache.
# Key '-5839258768785096567' not in persistent cache.
# Key '6068676594376395171' not in persistent cache.
# Key '-6198596713643233087' not in persistent cache.
# Key '8057300078972122301' not in persistent cache.
# Key '1326510295980508799' not in persistent cache.
# Key '-685618026900216519' not in persistent cache.
# Key '-2603387160907508812' not in persistent cache.
# Key '215510799220857361' not in persistent cache.
# Key '3808459517481291719' not in persistent cache.
# Key '6413608138750120282' not in persistent cache.
# Key '726042973650840945' not in persistent cache.
# Key '7311417265076570176' not in persistent cache.
# Key '-2930259643737186165' not in persistent cache.
# Key '7520655423725319589' not in persistent cache.
# Key '27231174643136303' not in persistent cache.
# Key '3413313121747988500' not in persistent cache.
# Key '1564380486190626150' not in persistent cache.
# Key '5535787725125165696' not in persistent cache.
# Key '-8778146346582244356' not in persistent cache.
# Key '2523185704703689876' not in persistent cache.
# Key '4937693129347825616' not in persistent cache.
# Key '-2730646248007164504' not in persistent cache.
# Key '-648198321588618677' not in persistent cache.
# Key '6470782787748445273' not in persistent cache.
# Key '-469726792844921204' not in persistent cache.
# Key '-2291016976847689100' not in persistent cache.
# Key '-1521983176500284549' not in persistent cache.
# Key '-831758071387587716' not in persistent cache.
# Key '-3095578545904494114' not in persistent cache.
# Key '6096648153539990977' not in persistent cache.
# Key '1799266133062477006' not in persistent cache.
# Key '1013123234937514238' not in persistent cache.
# Key '2007232027826786028' not in persistent cache.
# Key '2743920981887914012' not in persistent cache.
# Key '4592820017267324473' not in persistent cache.
# Key '165506375292450833' not in persistent cache.
# Key '697816706671853534' not in persistent cache.
# Key '1862611160142851692' not in persistent cache.
# Key '-8256562520210310123' not in persistent cache.
# Key '-5020228815523048803' not in persistent cache.
# Key '-5119861891387053609' not in persistent cache.
# Key '-8769716598330590843' not in persistent cache.
# Key '-1662064196555671903' not in persistent cache.
# Key '325496869256914235' not in persistent cache.
# Key '7794820168259221581' not in persistent cache.
# Key '-3035962134978544186' not in persistent cache.
# Key '-1249421221200293111' not in persistent cache.
# Key '9194909521118739112' not in persistent cache.
# Key '7542394839411524568' not in persistent cache.
# Key '3750385575238285836' not in persistent cache.
# Key '-8161216411470536037' not in persistent cache.
# Key '-7997884929603738767' not in persistent cache.
# Key '-5318606621003625619' not in persistent cache.
# Key '-5064369208454299656' not in persistent cache.
# Key '-1799537106455741350' not in persistent cache.
# Key '8485819790613915094' not in persistent cache.
# Key '8649151272480712364' not in persistent cache.
# Key '4958860016526942538' not in persistent cache.
# Key '-6278523286680954983' not in persistent cache.
# Key '-4856966614126889444' not in persistent cache.
# Key '2352394156374764651' not in persistent cache.
# Key '-1337897099579005175' not in persistent cache.
# Key '-8326815491700478862' not in persistent cache.
# Key '1504712690887905243' not in persistent cache.
# Key '9167902175870831677' not in persistent cache.
# Key '5023782205435789512' not in persistent cache.
# Key '-5419994317472455681' not in persistent cache.
# Key '-9212003581645694413' not in persistent cache.
# Key '-2676861494644964670' not in persistent cache.
# Key '-6911887395762535528' not in persistent cache.
# Key '165748295821945748' not in persistent cache.
# Key '-3978371674613096417' not in persistent cache.
# Key '-7759568861249394936' not in persistent cache.
# Key '-4476569366270065155' not in persistent cache.
# Key '-8711595267387636013' not in persistent cache.

# %% [markdown]
# ## [A] Population Statistics
#
# This function returns a query response to the question: 'In [year] how many [people/males/females] aged [low] to [high] were living in [the world/region/country]?'
#
#  Please note, this function was designed to be able to answer **only** the regions of countries targeted in Operation Condor, as that is the main focus region for our team.

# %%
import math
#def population(year,sex,age_low, age_high,place):
SOURCE = 40

def age_floor_lessthan_25(age_low, age_high, labels, sex):
    
    for i in np.arange(age_low, age_high+1):
        
            if sex == 'males':
                #labels[f'SP.POP.AG{str(i).zfill(2)}.MA.IN'] = f'SP.POP.AG{str(i).zfill(2)}.MA.IN'
                labels[f'SP.POP.AG{str(i).zfill(2)}.MA.IN'] = f'Males {str(i).zfill(2)}'
            elif sex == 'females':
                labels[f'SP.POP.AG{str(i).zfill(2)}.FE.IN'] = f'Females {str(i).zfill(2)}'
                #labels[f'SP.POP.AG{str(i).zfill(2)}.FE.IN'] = f'SP.POP.AG{str(i).zfill(2)}.FE.IN'
            else:
                #labels[f'SP.POP.AG{str(i).zfill(2)}.MA.IN'] = f'SP.POP.AG{str(i).zfill(2)}.MA.IN'
                #labels[f'SP.POP.AG{str(i).zfill(2)}.FE.IN'] = f'SP.POP.AG{str(i).zfill(2)}.FE.IN'   
                labels[f'SP.POP.AG{str(i).zfill(2)}.FE.IN'] = f'Females {str(i).zfill(2)}'
                labels[f'SP.POP.AG{str(i).zfill(2)}.MA.IN'] = f'Males {str(i).zfill(2)}'
                
def age_floor_greaterthan_25(age_low, age_high, labels, sex):
        age_floor = math.floor(age_low /5) * 5
        age_ceiling = math.ceil((age_high+1)/5)*5 
        floor_str = str(age_floor).zfill(2)
        num_ranges = (age_ceiling - age_floor) / 5
        for i in np.arange(num_ranges):
            lower_str = str(int(age_floor+5*i))
            higher_str = str(int(age_floor+5*i+4))
             #override if age is >=80
            if lower_str >='80':
                lower_str = "80"
                higher_str = 'UP'
            if sex == 'males':
                labels[f'SP.POP.{lower_str}{higher_str}.MA'] = f'Males {lower_str}{higher_str}'
            elif sex == 'females':
                labels[f'SP.POP.{lower_str}{higher_str}.FE'] = f'Females {lower_str}{higher_str}'
            else:
                #labels[f'SP.POP.AG{str(i).zfill(2)}.FE.IN'] = f'SP.POP.AG{str(i).zfill(2)}.FE'
                labels[f'SP.POP.{lower_str}{higher_str}.FE'] = f'Females {lower_str}{higher_str}'
                labels[f'SP.POP.{lower_str}{higher_str}.MA'] = f'Males {lower_str}{higher_str}'


#correct age range:
def range(age_low, age_high, sex): 
    labels = {}
    
    labels_test1 = {}
    age_floor_lessthan_25(0, 24, labels_test1, 'males')
    assert 'SP.POP.AG00.MA.IN' in labels_test1 and 'SP.POP.AG24.MA.IN' in labels_test1, "Failed to retrieve data for ages < 25"

    labels_test2 = {}
    age_floor_greaterthan_25(25, 39, labels_test2, 'females')
    assert 'SP.POP.2529.FE' in labels_test2 and 'SP.POP.3539.FE' in labels_test2, "Failed to retrieve data for ages >= 25"

    #age range [0,25]
    if age_high < 25:
        age_floor_lessthan_25(age_low, age_high, labels, sex)
    #age range [25, +]
    elif age_low >= 25:
        age_floor_greaterthan_25(age_low, age_high, labels, sex)
    #age range [0, 25+]
    else:
        age_floor_lessthan_25(age_low, 24, labels, sex)
        age_floor_greaterthan_25(25, age_high, labels, sex)
        
    return labels



def get_region_df(labels, age_high, sex, place, year):
    df = wbdata.get_dataframe(labels,country = place,parse_dates=True)
    df = df.reset_index()
    df2 = df[df['date'] == f'{year}-01-01']

    #if the age high is >25 and <80 and not a multiple of 5, then take a proportional fraction of the last column
    #example: 27, in range [25, 29] want (27%5 /5)
    #doesn't account for ages 81, 82, 83, etc (difficult to interpolate when so little data on older ages)
    if ((age_high>=25) & (age_high<80) & (age_high%5 != 4)):
        
        population_count = df2.iloc[0, -1]
        display(f'population count: {population_count}')
        proportion = (age_high%5+1) / 5
        df2.iloc[0, -1] = proportion*population_count
        
    return df2
#df = get_df(labels, sex, place, year)
#labels = range(22, 77, 'males')
#df = get_df(labels, 77, 'females', 'COL', 2022)
#df


def population(sex, age_low, age_high, place, year):
    # Error handling for invalid age range
    if age_low > age_high:
        raise ValueError(f"Invalid age range: ({age_low}) < ({age_high}). Please reverse the input age ranges.")

    # Validate `place` is a valid location in wbdata
    ls_countries = wbdata.get_countries()
    country_codes = [country['id'] for country in ls_countries]
    
    if place not in country_codes:
        raise ValueError(f"Invalid country code: {place}. Please enter a valid country. Call wbdata.get_countries to see the valid list of countries.")


    labels = range(age_low, age_high, sex)
     
    #unit test for age edge cases (if highest age lies in an interval)
    tlabels = {'SP.POP.2529.MA': 'Males 25-29'}
    df_test = get_region_df(tlabels, 27, sex, place, year)
    assert df_test.iloc[0, -1] <= df_test.iloc[0, 1], "Population proportion adjustment error!"
    
    df = get_region_df(labels, age_high, sex, place, year)
    df.drop('date', axis = 1, inplace=True)
    df['total pop in age range'] = df.sum(axis=1)
    total = df.iloc[0]['total pop in age range']
    display(f'In {year}, the number of {sex} between ages {age_low} to {age_high} living in {place} was approximately {total}')
    return df

#df_test = population('males', 0, 100, 'COL', 2000)
#assert df_test.iloc[0]['total pop in age range'] > 1e9 / 2, "Too few males in world population!"

population('males', 0, 99, 'WLD', 2000)
#df_test

# %% [markdown]
# ## [B] Population DataFrames
# This function returns a pandas DataFrame indexed by Region or Country and Year, with columns giving counts of people in different age-sex groups. For the means of Team Malthus' project focus, this function was designed to produce specifics for **only** regions/countries we are focussing on: the countries directly targeted impacted by Operation Condor.

# %%
#wbdata.get_countries()

# %%
condor_countries = {'ARG': 'Argentina', 'BOL': 'Bolivia', 'BRA': 'Brazil', 'CHL': 'Chile', 'ECU': 'Ecuador', 'CLA':'Latin America and the Caribbean (IFC classification)', 'WLD' :"World"}
#labels = range(22, 77, 'females')
#df = get_df(labels, 77, 'females', 'COL', 2022)
#df


def get_region_df(age_low, age_high, sex, place, year):
    labels = range(age_low, age_high, sex)
    df = wbdata.get_dataframe(labels,country = place,parse_dates=True)
    df = df.reset_index()
    df2 = df[df['date'] == f'{year}-01-01']
    df2['date'] = year
    #if the age high is >25 and <80 and not a multiple of 5, then take a proportional fraction of the last column
    #example: 27, in range [25, 29] want (27%5 /5)
    if ((age_high>=25) & (age_high<80) & (age_high%5 != 4)):
        population_count = df2.iloc[0, -1]
        display(f'population count: {population_count}')
        proportion = (age_high%5+1) / 5
        df2.iloc[0, -1] = proportion*population_count
        
        
    return df2

get_region_df(22, 77, 'females',condor_countries, 2021)
# Out:
# /tmp/ipykernel_76/1665431826.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['date'] = year
# 'population count: 602985.0'
#        country  date  Females 22  Females 23  Females 24  Females 2529  \
# 2    Argentina  2021    340990.0    339364.5    341034.0     1727965.0
# 66     Bolivia  2021    109809.5    108289.5    107373.5      518258.0
# 130     Brazil  2021   1649095.0   1655825.0   1646923.0     8105921.0
# 194      Chile  2021    140459.5    145160.0    149702.0      792156.0
# 258    Ecuador  2021    155491.5    155337.5    155166.0      755239.0
# 322      World  2021         NaN         NaN         NaN   290638670.0
#
#      Females 3034  Females 3539  Females 4044  Females 4549  Females 5054  \
# 2       1651617.0     1583375.0     1548702.0     1372580.0     1183031.0
# 66       469786.0      400557.0      349190.0      297321.0      251647.0
# 130     8299446.0     8539224.0     8027939.0     7135873.0     6449326.0
# 194      795033.0      725313.0      675065.0      649398.0      629116.0
# 258      701586.0      648686.0      574585.0      505627.0      442048.0
# 322   296697604.0   274546997.0   246000086.0   234930861.0   223923211.0
#
#      Females 5559  Females 6064  Females 6569  Females 7074  Females 7579
# 2       1095091.0     1017473.0      914976.0      777595.0      361791.0
# 66       210244.0      169351.0      128503.0       96082.0       68510.0
# 130     6076687.0     5236762.0     4186711.0     3107121.0     2055915.0
# 194      586850.0      520887.0      436213.0      342926.0      236452.0
# 258      377253.0      313465.0      256287.0      198079.0      137218.0
# 322   202156613.0   165292891.0   144946891.0   108698089.0    71377606.0
